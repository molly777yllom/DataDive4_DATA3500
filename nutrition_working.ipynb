# %% [markdown]
# # Nutritional Facts for most common foods
# Source: https://www.kaggle.com/datasets/niharika41298/nutrition-details-for-most-common-foods
# (this is the larger dataset)

# %% [markdown]
# ### Possible scenario ??:
# - A nutritionist creates custom diet plans for clients with medically-necessary dietary needs and wellness goals
# - They want to be able to break down prescribed diets by the meal and the recipe, and to have the ability to specify calories, macro and micronutrients, and vitamins/minerals
# - We have met with the client and obtained the following dataset detailing this information for an array of pre-defined meals. The nutritionist would like to be able to input their client's nutrition requirements and discover which meals to offer the client.
# - This input contains several parts:
# 1. what the client likes and doesn't like to eat
# 2. the nutritionist's breakdown specifying the client's prescription for that meal.
#
# - The returned result will be the meals which fit the client's taste and nutritional needs.
# - We will first study and organize the dataset to pick up on patterns across the food types
# - Then we can create a hypothetical plan for the best way for the end user (the nutritionist) to access and manipulate the data. Like a program, database, etc.
# - Further, we could see if the nutritionist's meal options are sufficient by examinig how many options are available for different dietary needs
#
# ### Questions
# 1. What

# %% [markdown]
# ### Data Acquisition
#
# preview of `nutrition.csv`:

# %%
import pandas as pd
# create dataframe
nutrition = pd.read_csv("nutrition.csv")
# display a preview
nutrition.head()
# Out:
#    Unnamed: 0             name serving_size  calories total_fat saturated_fat  \
# 0           0       Cornstarch        100 g       381      0.1g           NaN
# 1           1     Nuts, pecans        100 g       691       72g          6.2g
# 2           2    Eggplant, raw        100 g        25      0.2g           NaN
# 3           3   Teff, uncooked        100 g       367      2.4g          0.4g
# 4           4  Sherbet, orange        100 g       144        2g          1.2g
#
#   cholesterol    sodium  choline     folate  ...      fat  \
# 0           0   9.00 mg   0.4 mg   0.00 mcg  ...   0.05 g
# 1           0   0.00 mg  40.5 mg  22.00 mcg  ...  71.97 g
# 2           0   2.00 mg   6.9 mg  22.00 mcg  ...   0.18 g
# 3           0  12.00 mg  13.1 mg          0  ...   2.38 g
# 4         1mg  46.00 mg   7.7 mg   4.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
# 4               1.160 g                     0.530 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
# 2                     0.076 g                 0.00 mg   0.0 g  0.66 g
# 3                     1.071 g                       0       0  2.37 g
# 4                     0.080 g                 1.00 mg   0.0 g  0.40 g
#
#   caffeine theobromine    water
# 0  0.00 mg     0.00 mg   8.32 g
# 1  0.00 mg     0.00 mg   3.52 g
# 2  0.00 mg     0.00 mg  92.30 g
# 3        0           0   8.82 g
# 4  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 77 columns]

# %%
# print the number of cols, rows
print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\nThere are " + str(nutrition.shape[1]) + " columns and " + str(nutrition.shape[0]) + " rows.\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n")
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# There are 77 columns and 8789 rows.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
# basic statistics for the numerical columns
nutrition.describe()
# Out:
#         Unnamed: 0     calories  lucopene
# count  8789.000000  8789.000000    8789.0
# mean   4394.000000   226.283878       0.0
# std    2537.310091   169.862001       0.0
# min       0.000000     0.000000       0.0
# 25%    2197.000000    91.000000       0.0
# 50%    4394.000000   191.000000       0.0
# 75%    6591.000000   337.000000       0.0
# max    8788.000000   902.000000       0.0

# %%
# show the data types
nutrition.dtypes
# Out:
# Unnamed: 0       int64
# name            object
# serving_size    object
# calories         int64
# total_fat       object
#                  ...
# alcohol         object
# ash             object
# caffeine        object
# theobromine     object
# water           object
# Length: 77, dtype: object

# %%
# print all the column names
nutrition.columns
# Out:
# Index(['Unnamed: 0', 'name', 'serving_size', 'calories', 'total_fat',
#        'saturated_fat', 'cholesterol', 'sodium', 'choline', 'folate',
#        'folic_acid', 'niacin', 'pantothenic_acid', 'riboflavin', 'thiamin',
#        'vitamin_a', 'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
#        'fat', 'saturated_fatty_acids', 'monounsaturated_fatty_acids',
#        'polyunsaturated_fatty_acids', 'fatty_acids_total_trans', 'alcohol',
#        'ash', 'caffeine', 'theobromine', 'water'],
#       dtype='object')

# %% [markdown]
# #### unique values

# %%
# display the number of unique values in each categorical column
object_columns = nutrition.select_dtypes(include=['object']).columns  # set up a list of only the `object` dtypes

for column in object_columns:  # iterate thru columns list
    unique_count = nutrition[column].nunique()  # count how many unique values are present 
    print(f"There are {unique_count} different values in `{column}`.")  # print the number in the specified format
# Out:
# There are 8789 different values in `name`.
# There are 1 different values in `serving_size`.
# There are 176 different values in `total_fat`.
# There are 156 different values in `saturated_fat`.
# There are 313 different values in `cholesterol`.
# There are 1245 different values in `sodium`.
# There are 1197 different values in `choline`.
# There are 374 different values in `folate`.
# There are 259 different values in `folic_acid`.
# There are 3818 different values in `niacin`.
# There are 1479 different values in `pantothenic_acid`.
# There are 838 different values in `riboflavin`.
# There are 914 different values in `thiamin`.
# There are 1341 different values in `vitamin_a`.
# There are 566 different values in `vitamin_a_rae`.
# There are 215 different values in `carotene_alpha`.
# There are 582 different values in `carotene_beta`.
# There are 144 different values in `cryptoxanthin_beta`.
# There are 541 different values in `lutein_zeaxanthin`.
# There are 694 different values in `vitamin_b12`.
# There are 988 different values in `vitamin_b6`.
# There are 562 different values in `vitamin_c`.
# There are 242 different values in `vitamin_d`.
# There are 564 different values in `vitamin_e`.
# There are 564 different values in `tocopherol_alpha`.
# There are 513 different values in `vitamin_k`.
# There are 560 different values in `calcium`.
# There are 810 different values in `copper`.
# There are 952 different values in `irom`.
# There are 314 different values in `magnesium`.
# There are 1253 different values in `manganese`.
# There are 642 different values in `phosphorous`.
# There are 904 different values in `potassium`.
# There are 644 different values in `selenium`.
# There are 941 different values in `zink`.
# There are 2664 different values in `protein`.
# There are 1755 different values in `alanine`.
# There are 1888 different values in `arginine`.
# There are 2288 different values in `aspartic_acid`.
# There are 499 different values in `cystine`.
# There are 2983 different values in `glutamic_acid`.
# There are 1665 different values in `glycine`.
# There are 1207 different values in `histidine`.
# There are 370 different values in `hydroxyproline`.
# There are 1498 different values in `isoleucine`.
# There are 2182 different values in `leucine`.
# There are 2133 different values in `lysine`.
# There are 955 different values in `methionine`.
# There are 1375 different values in `phenylalanine`.
# There are 1587 different values in `proline`.
# There are 1389 different values in `serine`.
# There are 1431 different values in `threonine`.
# There are 466 different values in `tryptophan`.
# There are 1229 different values in `tyrosine`.
# There are 1627 different values in `valine`.
# There are 3322 different values in `carbohydrate`.
# There are 252 different values in `fiber`.
# There are 1917 different values in `sugars`.
# There are 409 different values in `fructose`.
# There are 52 different values in `galactose`.
# There are 410 different values in `glucose`.
# There are 204 different values in `lactose`.
# There are 217 different values in `maltose`.
# There are 468 different values in `sucrose`.
# There are 2422 different values in `fat`.
# There are 3951 different values in `saturated_fatty_acids`.
# There are 4010 different values in `monounsaturated_fatty_acids`.
# There are 2898 different values in `polyunsaturated_fatty_acids`.
# There are 314 different values in `fatty_acids_total_trans`.
# There are 49 different values in `alcohol`.
# There are 689 different values in `ash`.
# There are 62 different values in `caffeine`.
# There are 154 different values in `theobromine`.
# There are 4282 different values in `water`.

# %% [markdown]
# #### missing values
# 18% of the `saturated_fat` column is missing.

# %%
# check for missing values
missing_values = nutrition.isnull().sum()

# calculate missing value counts for those columns where missing values are greater than zero
missing_values_df = pd.DataFrame(missing_values[missing_values > 0], columns=['Count Missing'])

# calculate the percentage of missing values for each column
missing_pct = ((missing_values / nutrition.shape[0] * 100).round(3))
# add missing count and percent to table
missing_values_df["% Missing"] = missing_pct

# check if there are no missing values, and print a message if that's the case
if missing_values_df.empty:
    print("There are no missing values.")
else:
    # display the table if there are missing values
    display(missing_values_df)
# Out:
#                Count Missing  % Missing
# saturated_fat           1590     18.091

# %% [markdown]
# looks like there are a lot of entries where `total_fat` equals zero and `saturated_fat` is NaN. we can at least fill these values of `saturated_fat` with zero. We will do that after converting everything from strings to numerical values later on.

# %%
nutrition.query("total_fat == 0")
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, serving_size, calories, total_fat, saturated_fat, cholesterol, sodium, choline, folate, folic_acid, niacin, pantothenic_acid, riboflavin, thiamin, vitamin_a, vitamin_a_rae, carotene_alpha, carotene_beta, cryptoxanthin_beta, lutein_zeaxanthin, lucopene, vitamin_b12, vitamin_b6, vitamin_c, vitamin_d, vitamin_e, tocopherol_alpha, vitamin_k, calcium, copper, irom, magnesium, manganese, phosphorous, potassium, selenium, zink, protein, alanine, arginine, aspartic_acid, cystine, glutamic_acid, glycine, histidine, hydroxyproline, isoleucine, leucine, lysine, methionine, phenylalanine, proline, serine, threonine, tryptophan, tyrosine, valine, carbohydrate, fiber, sugars, fructose, galactose, glucose, lactose, maltose, sucrose, fat, saturated_fatty_acids, monounsaturated_fatty_acids, polyunsaturated_fatty_acids, fatty_acids_total_trans, alcohol, ash, caffeine, theobromine, water]
# Index: []
#
# [0 rows x 77 columns]

# %%
# check for missing values
missing_values = nutrition.isnull().sum()

# calculate missing value counts for those columns where missing values are greater than zero
missing_values_df = pd.DataFrame(missing_values[missing_values > 0], columns=['Count Missing'])

# calculate the percentage of missing values for each column
missing_pct = ((missing_values / nutrition.shape[0] * 100).round(3))
# add missing count and percent to table
missing_values_df["% Missing"] = missing_pct

# check if there are no missing values, and print a message if that's the case
if missing_values_df.empty:
    print("There are no missing values.")
else:
    # display the table if there are missing values
    display(missing_values_df)
# Out:
#                Count Missing  % Missing
# saturated_fat           1590     18.091

# %%
import missingno as msno
msno.matrix(nutrition)
# Out:
# <Axes: >

# %% [markdown]
# #### duplicate rows
# there are no duplicates.

# %%
# check for duplicate rows
duplicate_rows = nutrition.duplicated().sum()
print("There are " + str(duplicate_rows) + " duplicate row(s).\n")

# get a boolean series indicating which rows are duplicates (including the original rows)
duplicate_mask = nutrition.duplicated(keep=False)

# use mask to filter and display both the original and duplicate rows
duplicate_rows_df = nutrition[duplicate_mask]
duplicate_rows_df
# Out:
# There are 0 duplicate row(s).
# Empty DataFrame
# Columns: [Unnamed: 0, name, serving_size, calories, total_fat, saturated_fat, cholesterol, sodium, choline, folate, folic_acid, niacin, pantothenic_acid, riboflavin, thiamin, vitamin_a, vitamin_a_rae, carotene_alpha, carotene_beta, cryptoxanthin_beta, lutein_zeaxanthin, lucopene, vitamin_b12, vitamin_b6, vitamin_c, vitamin_d, vitamin_e, tocopherol_alpha, vitamin_k, calcium, copper, irom, magnesium, manganese, phosphorous, potassium, selenium, zink, protein, alanine, arginine, aspartic_acid, cystine, glutamic_acid, glycine, histidine, hydroxyproline, isoleucine, leucine, lysine, methionine, phenylalanine, proline, serine, threonine, tryptophan, tyrosine, valine, carbohydrate, fiber, sugars, fructose, galactose, glucose, lactose, maltose, sucrose, fat, saturated_fatty_acids, monounsaturated_fatty_acids, polyunsaturated_fatty_acids, fatty_acids_total_trans, alcohol, ash, caffeine, theobromine, water]
# Index: []
#
# [0 rows x 77 columns]

# %% [markdown]
# ## data cleaning
# - we know that most columns contain a mixture of numbers (for amounts) and units (g for grams, mg for milligrams, etc).
# - first, we check and see if the units in each column are similar to what we see in the dataset's .head() preview above, or if there are multiple units present in columns.
# - the result shows that no column contains more than one unit, but many also fall into the 'other' category. this could mean that there are other units we don't see in the .head(), or it could mean that there is no unit at all.

# %%
# define a function which accepts input of a string containing a number (for the amount) plus a unit (g, mg, or mcg)
def check_unit(value):

    # first, convert each value to a string so the function can be applied
    # if a value is present (non-null), assign the string version of each value to `str_value`. if a null is encountered, an empty string is added
    str_value = str(value) if value is not None else ''

    # classify each string of letters into the following categories using `if` critera
    if 'g' in str_value:
        return 'g'          # returns "g", detecting the input is in grams
    elif 'mg' in str_value:
        return 'mg'         # returns "mg", detecting the input is in milligrams
    elif 'mcg' in str_value:
        return 'mcg'         # returns "mcg", detecting the input is in micrograms
    else:
        return 'other'      # returns "other", detecting the input is something else

# define an empty dictionary with which to store results
column_units = {}

# this nested `for` loop applies `check_unit` function to all items in a df
for column in nutrition.select_dtypes(include=['object', 'float']):       # iterates through columns in given dataframe
    units_in_column = set()     # initializes an empty set called `units_in_columms` (a set is used because it will automatically show duplicates only once)
    for value in nutrition[column]:        # then, the nested loop iterates thru the values in each column
        unit = check_unit(value)    # the `check_unit` function is called for each value
        units_in_column.add(unit)   # the result returned from `check_unit` is then stored in the set, `units_in_column`
    column_units[column] = units_in_column  # once the inner loop finishes, the units found are stored in the `column_units` dictionary with column names as keys

column_units  # the results are printed
# Out:
# {'name': {'g', 'other'},
#  'serving_size': {'g'},
#  'total_fat': {'g'},
#  'saturated_fat': {'g', 'other'},
#  'cholesterol': {'g', 'other'},
#  'sodium': {'g', 'other'},
#  'choline': {'g', 'other'},
#  'folate': {'g', 'other'},
#  'folic_acid': {'g', 'other'},
#  'niacin': {'g', 'other'},
#  'pantothenic_acid': {'g', 'other'},
#  'riboflavin': {'g', 'other'},
#  'thiamin': {'g', 'other'},
#  'vitamin_a': {'g', 'other'},
#  'vitamin_a_rae': {'g', 'other'},
#  'carotene_alpha': {'g', 'other'},
#  'carotene_beta': {'g', 'other'},
#  'cryptoxanthin_beta': {'g', 'other'},
#  'lutein_zeaxanthin': {'g', 'other'},
#  'vitamin_b12': {'g', 'other'},
#  'vitamin_b6': {'g', 'other'},
#  'vitamin_c': {'g', 'other'},
#  'vitamin_d': {'other'},
#  'vitamin_e': {'g', 'other'},
#  'tocopherol_alpha': {'g', 'other'},
#  'vitamin_k': {'g', 'other'},
#  'calcium': {'g', 'other'},
#  'copper': {'g', 'other'},
#  'irom': {'g', 'other'},
#  'magnesium': {'g', 'other'},
#  'manganese': {'g', 'other'},
#  'phosphorous': {'g', 'other'},
#  'potassium': {'g', 'other'},
#  'selenium': {'g', 'other'},
#  'zink': {'g', 'other'},
#  'protein': {'g'},
#  'alanine': {'g', 'other'},
#  'arginine': {'g', 'other'},
#  'aspartic_acid': {'g', 'other'},
#  'cystine': {'g', 'other'},
#  'glutamic_acid': {'g', 'other'},
#  'glycine': {'g', 'other'},
#  'histidine': {'g', 'other'},
#  'hydroxyproline': {'g', 'other'},
#  'isoleucine': {'g', 'other'},
#  'leucine': {'g', 'other'},
#  'lysine': {'g', 'other'},
#  'methionine': {'g', 'other'},
#  'phenylalanine': {'g', 'other'},
#  'proline': {'g', 'other'},
#  'serine': {'g', 'other'},
#  'threonine': {'g', 'other'},
#  'tryptophan': {'g', 'other'},
#  'tyrosine': {'g', 'other'},
#  'valine': {'g', 'other'},
#  'carbohydrate': {'g'},
#  'fiber': {'g', 'other'},
#  'sugars': {'g', 'other'},
#  'fructose': {'g', 'other'},
#  'galactose': {'g', 'other'},
#  'glucose': {'g', 'other'},
#  'lactose': {'g', 'other'},
#  'maltose': {'g', 'other'},
#  'sucrose': {'g', 'other'},
#  'fat': {'g'},
#  'saturated_fatty_acids': {'g', 'other'},
#  'monounsaturated_fatty_acids': {'g', 'other'},
#  'polyunsaturated_fatty_acids': {'g', 'other'},
#  'fatty_acids_total_trans': {'g', 'other'},
#  'alcohol': {'g', 'other'},
#  'ash': {'g', 'other'},
#  'caffeine': {'g', 'other'},
#  'theobromine': {'g', 'other'},
#  'water': {'g', 'other'}}

# %% [markdown]
# - to determine what 'other' means for each column, we will modify the function to filter for numeric values.
# - the resulting output shows that the 'other' category just meant that a value doesn't have any unit .
# - the output shows that columns fall into one of four situations:
# 1. all values in the column are non-numeric. (`name` column)
# 2. all values in the column are numeric. (`calories`, `lucopene`)
# 3. all values in the column have some unit
# 4. some values in the column have a unit, some are numeric-only. for the ones with unit, the unit is the same throughout the column. since we're not sure whether numeric-only just means the unit was forgotten or whether it indicates something in particular, we will keep this in mind when the time comes to analyze the data.
# 5. some values in the column have a unit, some are missing (nan). for the ones with unit, the unit is the same throughout the column. (the only column this applies to is `saturated_fat`).

# %%
# define a function which accepts input of a string containing a number (for the amount) plus a unit (g, mg, or mcg)
def check_unit(value):

    # first, convert each value to a string so the function can be applied
    # if a value is present (non-null), assign the string version of each value to `str_value`. if a null is encountered, an empty string is added
    str_value = str(value) if value is not None else ''
    
    # then, extract non-numeric information from each item in `str_value` and assign the result to `non_numeric`
    # the filter() tests each string using the lambda, which iterates thru the string and captures only non-digits and decimals ('.')
    # the outer method, ''.join(), concatenates any non-numeric characters found into one string
    # .strip() removes extra white spaces
    non_numeric = ''.join(filter(lambda x: not x.isdigit() and x != '.', str_value)).strip()
    return non_numeric if non_numeric else 'numeric'  # if `non_numeric` contains information it is returned; if it is empty, `numeric` is returned

# define an empty dictionary with which to store results
column_units = {}

# this nested `for` loop applies `check_unit` function to all items in a df
for column in nutrition.select_dtypes(include=['object', 'float', 'int']).columns:   # iterates through columns in given dataframe
    units_in_column = set()     # initializes an empty set called `units_in_columms` (a set is used because it will automatically show duplicates only once)
    for value in nutrition[column]:        # then, the nested loop iterates thru the values in each column
        unit = check_unit(value)    # the `check_unit` function is called for each value
        units_in_column.add(unit)   # the result returned from `check_unit` is then stored in the set, `units_in_column`
    column_units[column] = units_in_column  # once the inner loop finishes, the units found are stored in the `column_units` dictionary with column names as keys

column_units  # the results are printed
# Out:
# {'Unnamed: 0': {'numeric'},
#  'name': {'Infant formula, with ARA and DHA, not reconstituted, powder, with iron, NUTRAMIGEN LIPIL, ENFAMIL, MEAD JOHNSON',
#   'Alcoholic Beverage, Petite Sirah, red, table, wine',
#   'Beef, raw, choice, trimmed to /" fat, separable lean only, boneless, top sirloin cap steak, loin',
#   'Celery, with salt, drained, boiled, cooked',
#   'Lemonade, prepared with water, powder',
#   'Fast foods, caramel, sundae',
#   'LOMA LINDA Swiss Stake with Gravy, unprepared, canned',
#   'Agave, raw (Southwest)',
#   'Beef, grilled, cooked, choice, trimmed to " fat, separable lean only, boneless, shoulder steak',
#   'Pork, roasted, cooked, separable lean only, boneless, sirloin (roasts), loin, fresh',
#   'Pork, unheated, separable lean only, boneless, whole, ham and water product, cured',
#   'Breakfast bars, coconut (include granola bar), raisins, sugar, oats',
#   'Beef, smoked, cooked, sausage, cured',
#   'Chicken, raw, meat only, leg, broilers or fryers',
#   'Bread, bollilo, Mexican, roll',
#   'Soup, lower sodium, beef broth, SWANSON',
#   'KASHI Mayan Harvest Bake, unprepared, frozen',
#   'Lamb, fast roasted, cooked, separable lean only, loin saddle, imported, New Zealand',
#   'Beverages, powder, chocolate, malted drink mix',
#   'Beef, raw, all grades, trimmed to " fat, separable lean only, bone-in, back ribs, rib',
#   'Raisins, golden seedless',
#   'Salad dressing, fat-free, caesar',
#   'Babyfood, strained, apples and chicken, dinner',
#   'Pokeberry shoots, without salt, drained, boiled, cooked, (poke)',
#   'Currants, dried, zante',
#   'Sauce, ready-to-serve, spaghetti/marinara, pasta',
#   'Bread, cinnamon',
#   'Pork, roasted, cooked, separable lean and fat, arm picnic, shoulder, fresh',
#   "KELLOGG'S, Multigrain Crackers, SPECIAL K",
#   'Peppers, solids and liquids, canned, jalapeno',
#   'Cereals ready-to-eat, FRANKENBERRY, GENERAL MILLS',
#   'Babyfood, strained, macaroni and tomato and beef, dinner',
#   "McDONALD'S, Hotcakes and Sausage",
#   'Babyfood, dry fortified, barley, cereal',
#   'Turkey, with broth, meat only, canned',
#   'Lima beans, with salt, boiled, cooked, mature seeds, large',
#   'Seeds, raw, lotus seeds',
#   'Beef, raw, choice, trimmed to /" fat, separable lean only, lip-on, boneless, rib eye steak/roast',
#   'Reddi Wip Fat Free Whipped Topping',
#   'Pork, roasted, cooked, separable lean only, bone-in, sirloin (roasts), loin, fresh',
#   'Beef, raw, choice, trimmed to " fat, separable lean and fat, boneless, mock tender steak, chuck',
#   'Cardoon, with salt, drained, boiled, cooked',
#   'Soup, condensed, canned, mushroom with beef stock',
#   'USDA Commodity, frozen, Potato wedges',
#   'Pie, prepared from recipe, vanilla cream',
#   'Caribou, raw (Alaska Native), tongue',
#   'Fish, raw (Alaska Native), meat, lingcod',
#   'Beverages, peanut flavor, canned, Meal supplement drink',
#   'Crackers, water biscuits',
#   'Beef, broiled, cooked, select, trimmed to /" fat, separable lean and fat, whole (ribs -), rib',
#   'Beef, roasted, cooked, select, trimmed to /" fat, separable lean and fat, boneless, top loin petite roast',
#   'Fast foods, with condiments, regular patty and bun, double, cheeseburger',
#   'Crustaceans, canned, mixed species, shrimp',
#   'Pork, roasted, cooked, separable lean and fat, rump half, leg (ham), fresh',
#   'Beans, with pork and tomato sauce, canned, baked',
#   'Beef, roasted, cooked, all grades, trimmed to /" fat, separable lean and fat, lip-on, bone-in, rib eye roast',
#   'Snacks, wasabi-flavored, roasted, peas',
#   'Pork, pan-broiled, cooked, separable lean and fat, boneless, center loin (chops), loin, fresh',
#   'Chicken, roasted, cooked, meat only, wing, broilers or fryers',
#   'Formulated bar, SNICKERS MARATHON Double Chocolate Nut Bar, MARS SNACKFOOD US',
#   'Beans, drained solids, no salt added, canned, green, snap',
#   'Ostrich, raw, ground',
#   'Nuts, blanched, almonds',
#   'Beef, raw, choice, trimmed to /" fat, separable lean and fat, t-bone steak, short loin',
#   'English muffins, with calcium propionate (includes sourdough), unenriched, plain',
#   'ARCHWAY Home Style Cookies, Iced Molasses',
#   'Beverages, cola, ZEVIA',
#   'Babyfood, junior, with egg yolks, cereal',
#   'Mung beans, with salt, boiled, cooked, mature seeds',
#   'Apples, heated, unsweetened, frozen',
#   'Peanuts, raw, spanish',
#   'Snacks, made with olestra, fat-free, made from dried potatoes, potato chips',
#   'Babyfood, strained, applesauce and cherries, fruit',
#   'Chicken, roasted, cooked, meat only, back, broilers or fryers',
#   'Lemon juice from concentrate, canned or bottled',
#   'Wheat germ, crude',
#   'Lemonade, white, frozen concentrate',
#   'Cereals ready-to-eat, Fruity DYNO-BITES, MALT-O-MEAL',
#   'Beverages, Citrus,  Energy drink',
#   'Mung beans, raw, mature seeds',
#   'Babyfood, junior, ham, meat',
#   'Fish, dry heat, cooked, monkfish',
#   'Fat, duck',
#   'Beef, grilled, cooked, select, trimmed to /" fat, separable lean and fat, top loin, loin',
#   'Beef, raw, separable lean and fat, tenderloin, imported, New Zealand',
#   'Mushrooms, grilled, exposed to ultraviolet light, portabella',
#   'KEEBLER, Reduced Fat, Vienna Fingers with Creme Filling',
#   'Cereals ready-to-eat, bagged cereal, Shredded Wheat, QUAKER',
#   'Restaurant, Arroz con grandules (rice and pigeonpeas), Latino',
#   'Spices, dill seed',
#   'Margarine-like spread, SMART BALANCE Light Buttery Spread',
#   'Pasta, cooked, made with egg, homemade',
#   'Turkey, raw, meat and skin, thigh, retail parts',
#   'Salad dressing, with salt, regular, mayonnaise type',
#   'Nuts, lightly salted, without peanuts, oil roasted, mixed nuts',
#   'Cookies, with creme filling, chocolate sandwich, gluten-free',
#   'Nuts, packaged, flaked, sweetened, dried (desiccated), coconut meat',
#   'Fish, drained solids, canned in oil, european, anchovy',
#   "Candies, POP'ABLES MILKY WAY Brand Bite Size Candies, MARS SNACKFOOD US",
#   'Toppings, butterscotch or caramel',
#   'Juice, with added ascorbic acid, apple and grape blend',
#   'Lamb, broiled, cooked, choice, trimmed to /" fat, separable lean only, arm, shoulder, domestic',
#   'Shallots, freeze-dried',
#   'Crustaceans, moist heat, cooked, dungeness, crab',
#   'Cornmeal, yellow (Navajo)',
#   'KEEBLER, bite-size, Cinnamon Grahams, GRIPZ',
#   'Beef, raw, choice, trimmed to " fat, separable lean only, boneless, ribeye  petite roast/filet',
#   'Snacks, made with enriched masa flour, nacho-flavor, tortilla chips',
#   'Pork, broiled, cooked, separable lean and fat, boneless, petite tender, shoulder',
#   'Beans, raw, green, snap',
#   'KEEBLER, Dark Chocolate Chunk Cookies, CHIPS DELUXE',
#   'Brussels sprouts, without salt, drained, boiled, cooked, frozen',
#   'Poi',
#   'Chicken, roasted, cooked, meat only, dark meat, broilers or fryers',
#   'Potatoes, whole milk and butter added, prepared from granules without milk, dehydrated, mashed',
#   'Infant Formula, ready-to-feed, GENTLE PLUS, GERBER GOOD START',
#   "DENNY'S, french fries",
#   'Sour dressing, filled cream-type, cultured, non-butterfat',
#   'Beef, grilled, cooked, choice, trimmed to /" fat, separable lean and fat, t-bone steak, short loin',
#   'Beef, braised, cooked, choice, trimmed to " fat, separable lean and fat, boneless, under blade pot roast, chuck',
#   'Cattail, Narrow Leaf Shoots (Northern Plains Indians)',
#   'Pork, pan-broil, heated, separable lean and fat, bone-in, slice, ham and water product, cured',
#   "Cereals ready-to-eat, Cinnamon Almond, KELLOGG'S RAISIN BRAN, KELLOGG",
#   'Soup, condensed, canned, new england, clam chowder',
#   'Kohlrabi, with salt, drained, boiled, cooked',
#   'KEEBLER, Mini Mints Grasshopper Cookies, FUDGE SHOPPE,  Calorie RIGHT BITES',
#   'HORMEL, Cure  Ham',
#   'Candies, TWIX Caramel Cookie Bars, MARS SNACKFOOD US',
#   'Pork, raw, with added solution, separable lean and fat, boneless, top loin (chops), loin, fresh',
#   'Candies, milk chocolate coated peanuts',
#   'Fast foods, with ham, biscuit',
#   'Beef, raw, all grades, trimmed to " fat, separable lean and fat, steak, top blade, shoulder clod, chuck',
#   'Cheese food, without added vitamin D, American, pasteurized process',
#   'Cabbage, raw, stored, common (danish, domestic, and pointed types)',
#   'Mushrooms, dried, shiitake',
#   'Pork, broiled, cooked, separable lean and fat, boneless, top loin (chops), loin, fresh',
#   'Croissants, butter',
#   'Beverages, Energy Drink with carbonated water and high fructose corn syrup',
#   'Oranges, Florida, raw',
#   'Emu, broiled, cooked, fan fillet',
#   "CAMPBELL'S Red and White - Microwaveable Bowls, Tomato Soup",
#   'Beef, raw, choice, trimmed to /" fat, separable lean only, flat half, brisket',
#   'Vegetables, without salt, drained, boiled, cooked, frozen, mixed',
#   'Fish, smoked and canned (Alaska Native), chinook, king, salmon',
#   'Cherries, raw, sweet',
#   'Lamb, braised, cooked, pancreas, variety meats and by-products',
#   'Beef, raw, all grades, trimmed to " fat, separable lean only, boneless, shoulder top blade steak',
#   'Tomato products, with salt added, puree, canned',
#   'Crustaceans, moist heat, cooked, mixed species, spiny lobster',
#   'Muffins, made with low fat (%) milk, prepared from recipe, blueberry',
#   'Beef, slow roasted, cooked, separable lean only, eye round, imported, New Zealand',
#   'Fish, raw, spot',
#   'Fish, dried and salted, Atlantic, cod',
#   'Veal, raw, separable lean only, rib',
#   'Bananas, raw',
#   'Cornmeal, enriched, plain, bolted, self-rising, white',
#   'Squash, raw, all varieties, summer',
#   'Fast food, biscuit',
#   'Grapefruit, California and Arizona, pink and red, raw',
#   'Light Ice Cream, blended with milk chocolate candies, soft serve',
#   'SUNSHINE, BIG Crackers, CHEEZ-IT',
#   "CAMPBELL'S CHUNKY Soups, Grilled Sirloin Steak with Hearty Vegetables Soup",
#   'Beans, with salt, drained, boiled, cooked, sprouted, mature seeds, kidney',
#   'Pork, unheated, separable lean and fat, boneless, whole, ham and water product, cured',
#   'Pasta, as purchased, plain, fresh-refrigerated',
#   'Turkey breast, luncheon meat, prepackaged or deli, low salt',
#   'Malabar spinach, cooked',
#   'Lamb, raw, ground',
#   'Tomatoes, stewed, cooked, ripe, red',
#   'Fish, solids and liquid, canned, Atlantic, cod',
#   'Beef, raw, all grades, separable lean only, whole, brisket',
#   'Cereals ready-to-eat, BERRY COLOSSAL CRUNCH, MALT-O-MEAL',
#   "Cereals, dry, Ham 'n' Cheese flavor, Instant Grits, QUAKER",
#   'Fast foods, soft, lettuce and cheese, taco with chicken',
#   'Pork, broiled, cooked, separable lean only, boston (steaks), blade, shoulder, fresh',
#   'Cheese, low moisture, whole milk, mozzarella',
#   'Soup, prepared with water, cubed, beef broth',
#   'Breakfast bar, corn flake crust with fruit',
#   'PAPA JOHN\'S " The Works Pizza, Original Crust',
#   'Cherries, drained, water pack, canned, sour',
#   'KEEBLER, Chocolate Chip Cookies, CHIPS DELUXE,  Calorie RIGHT BITES',
#   'Squash, without salt, solid, drained, canned, crookneck and straightneck, summer',
#   'Cheese, brie',
#   'Lamb, raw, separable lean only, rack - partly frenched, imported, New Zealand',
#   'Chicken, batter, fried, cooked, meat and skin, light meat, broilers or fryers',
#   'Veal, braised, cooked, separable lean only, blade, shoulder',
#   'Restaurant, onion rings, family style',
#   'Light ice cream, Creamsicle',
#   'Beef, braised, cooked, choice, trimmed to " fat, separable lean only, arm pot roast, chuck',
#   'LOMA LINDA Tender Rounds with Gravy, unprepared, canned',
#   'Beverages, lemon, ready-to-drink, black, tea, NESTEA',
#   'Snacks, plain, pork skins',
#   "CAMPBELL'S, Low Sodium V, V Vegetable Juice",
#   'Bread, rye, reduced-calorie',
#   'Beef, raw, all grades, trimmed to " fat, separable lean only, boneless, mock tender steak, chuck',
#   'GIRL SCOUTS, Thin Mints Cookies',
#   'Beef, raw, select, trimmed to " fat, separable lean and fat, boneless, chuck eye Country-Style ribs',
#   'Tomato products, sauce, canned',
#   'Winged beans, raw, mature seeds',
#   'Cookies, baked, refrigerated dough, peanut butter',
#   'Celtuce, raw',
#   'Lamb, raw, separable lean only, tenderloin, imported, New Zealand',
#   "WENDY'S, single, DAVE'S Hot 'N Juicy / LB",
#   'Beverages, powder, orange flavor, GATORADE, QUAKER OATS, drink mix',
#   "McDONALD'S, Sausage McMUFFIN",
#   "McDONALD'S, Sausage Burrito",
#   'PREGO Pasta, ready-to-serve, Fresh Mushroom Italian Sauce',
#   'WORTHINGTON FriChik Original, unprepared, canned',
#   'Grapefruit juice, sweetened, canned, white',
#   'Soybeans, with salt, boiled, cooked, mature seeds',
#   'Snacks, peanut butter and chocolate chip, uncoated, soft, granola bars',
#   'Hyacinth-beans, without salt, drained, boiled, cooked, immature seeds',
#   'Candies, dietetic or low calorie (sorbitol), hard',
#   'ON THE BORDER, cheese enchilada',
#   'Beef, grilled, cooked, all grades, trimmed to /" fat, separable lean and fat, lip-on, bone-in, rib eye steak',
#   'Beef, broiled, cooked, all grades, trimmed to " fat, separable lean and fat, inside skirt steak, plate',
#   'Lamb, roasted, cooked, choice, trimmed to /" fat, separable lean only, shank half, leg, domestic',
#   'Lamb, soaked and simmered, cooked, sweetbread, imported, New Zealand',
#   'Babyfood, strained, with eggs, cereal',
#   'Jute, with salt, drained, boiled, cooked, potherb',
#   'Sausage, smoked, pork and beef, Polish',
#   'Beef, raw, Aust marble score /, separable lean only, boneless, small end rib steak/roast, rib, Wagyu, imported, Australian',
#   'Fish, raw, king, mackerel',
#   'KEEBLER, Multigrain Crackers, TOPPERS, TOWN HOUSE',
#   'Beef, raw, all grades, trimmed to " fat, separable lean only, boneless, top round roast, round',
#   'Chickpeas (garbanzo beans, bengal gram), rinsed in tap water, drained, canned, mature seeds',
#   'Beef, grilled, cooked, all grades, trimmed to /" fat, separable lean only, lip-on, bone-in, rib eye steak',
#   'Zwieback',
#   'Soup, ready-to-serve, canned, reduced sodium, chunky vegetable',
#   'Ground turkey, broiled, patties, fat free',
#   'Rice and vermicelli mix, unprepared, beef flavor',
#   'Beverages, brewed, other than chamomile, herb, tea',
#   'Oil, multiuse for non-dairy butter flavor, soy (partially hydrogenated), industrial',
#   'Corned beef and potatoes in tortilla (Apache)',
#   'Bologna, beef and pork',
#   'Peppers, raw, green, sweet',
#   'TACO BELL, BURRITO SUPREME with chicken',
#   'Wild rice, cooked',
#   'Cereals ready-to-eat, Oatmeal Squares, QUAKER',
#   'Game meat, roasted, cooked, composite of cuts, domesticated, rabbit',
#   'Fish, raw, chinook, salmon',
#   'Peanuts, raw, all types',
#   'Asparagus, solids and liquids, regular pack, canned',
#   'Figs, stewed, dried',
#   "CAMPBELL'S CHUNKY Soups, Fajita Chicken with Rice & Beans Soup",
#   'Beef, broiled, cooked, choice, trimmed to /" fat, separable lean only, steak, top sirloin',
#   'Beef, braised, cooked, choice, trimmed to " fat, separable lean and fat, boneless, under blade steak, chuck',
#   'Cereals, without salt, stove-top, cooked with water,  minute cook time, CREAM OF WHEAT',
#   'Beverages, diet, lemon, ready-to-drink, tea',
#   'Potatoes, dry form, flakes without milk, dehydrated, mashed',
#   'Fat, mutton tallow',
#   'Beef, grilled, cooked, all grades, trimmed to " fat, separable lean only, boneless, ribeye filet',
#   'Cereals ready-to-eat, Wheat and Honey, Oats, % Natural Granola, QUAKER',
#   'Veal, raw, separable lean only, blade chop, shoulder',
#   'Pork, cooked, rendered fat, bacon',
#   'Fish, dry heat, cooked, farmed, rainbow, trout',
#   'Veal, raw, separable lean only, shank',
#   'Pork, unheated, separable lean only, bone-in, slice, ham, cured',
#   'Oil, principal use as a tortilla shortening, soy (partially hydrogenated)  and cottonseed, industrial',
#   'Beef, raw, choice, trimmed to /" fat, separable lean only, steak, top round, round',
#   'Pears, without added sugar, stewed, sulfured, dried',
#   'Snacks, graham and marshmallow, chocolate chip, uncoated, soft, granola bars',
#   'Restaurant, pupusas con frijoles (pupusas, bean), Latino',
#   'Cheese substitute, mozzarella',
#   'Cake, dry mix, carrot, pudding-type',
#   'Cookies, prepared from recipe, brownies',
#   'Potsticker or wonton, unprepared, frozen, pork and vegetable',
#   'Lamb, roasted, cooked, trimmed to /" fat, separable lean only, boneless, bottom, leg, fresh, imported, Australian',
#   'Fish, dry heat, cooked, milkfish',
#   'Lamb, raw, separable fat, fresh, imported, Australian',
#   'WORTHINGTON Meatless Corned Beef Roll, unprepared, frozen',
#   'Guinea hen, raw, meat only',
#   'Infant formula, not reconstituted, powder, with iron, PREGESTIMIL, MEAD JOHNSON',
#   'Lamb, braised, cooked, trimmed to /" fat, separable lean only, cubed for stew or kabob (leg and shoulder), domestic',
#   'Puddings, prepared with whole milk, dry mix, tapioca',
#   'Muffins, made with low fat (%) milk, prepared from recipe, plain',
#   'Beef, broiled, cooked, select, trimmed to /" fat, separable lean only, steak, top sirloin',
#   'Applesauce, without salt (includes USDA commodity), sweetened, canned',
#   'Formulated bar, all flavors, SNICKERS MARATHON Energy Bar, MARS SNACKFOOD US',
#   'Gravy, dry, brown',
#   'Peppers, sauteed, red, sweet',
#   'Fish, dry heat, cooked, pink, salmon',
#   'Fast foods, strawberry banana smoothie made with ice and low-fat yogurt',
#   "Candies, REESE'S BITES",
#   'Quail, raw, meat only, breast',
#   "McDONALD'S, Bacon Egg & Cheese Biscuit",
#   'Bread, toasted, commercially prepared, whole-wheat',
#   'Macaroni and cheese, prepared, box mix with cheese sauce',
#   'Game meat, roasted, cooked, horse',
#   'MORNINGSTAR FARMS Pizza, unprepared, frozen, single serve, Baja Black Bean',
#   'KEEBLER, Toast & Peanut Butter Sandwich Crackers',
#   'Artichokes, raw, (globe or french)',
#   'Salad dressing, regular, commercial, peppercorn dressing',
#   'Infant formula, with ARA and DHA, liquid concentrate, low iron, LIPIL, ENFAMIL, MEAD JOHNSON',
#   'Potatoes, home-prepared with margarine, scalloped',
#   'Hyacinth beans, with salt, boiled, cooked, mature seeds',
#   'Yambean (jicama), raw',
#   'Pancakes, prepared, incomplete, dry mix, whole-wheat',
#   'Buckwheat',
#   'Ice creams, Vanilla Chocolate Strawberry, No Sugar Added, BREYERS',
#   'Pasta, cooked, corn and rice flour, gluten-free',
#   "CAMPBELL'S Homestyle HEALTHY REQUEST Mexican Style Chicken Tortilla",
#   'Lamb, raw, brain, variety meats and by-products',
#   'Lamb, soaked and fried, cooked, brains, imported, New Zealand',
#   'KASHI, Frozen Entree, Lemongrass Coconut Chicken',
#   'Beef, roasted, cooked, select, trimmed to /" fat, separable lean and fat, roast, tenderloin',
#   'Beef, raw, all grades, trimmed to /" fat, separable lean and fat, porterhouse steak, short loin',
#   'Lamb, raw, brains, imported, New Zealand',
#   'Beverages, diet, peach, ready-to-drink, black, tea',
#   'Puddings, with added oil, regular, dry mix, banana',
#   'Cereals ready-to-eat, POST Raisin Bran Cereal',
#   "CAMPBELL'S Red and White - Microwaveable Bowls, Vegetable Beef Soup",
#   'KEEBLER, Club & Cheddar Sandwich Crackers',
#   'Game meat, roasted, cooked, elk',
#   'Cabbage, raw, red',
#   'Refried beans, reduced sodium, traditional, canned',
#   'Corn, with salt, drained, boiled, kernels cut off cob, frozen, white, sweet',
#   'Rice, cooked, enriched, medium-grain, white',
#   'French toast, ready-to-heat, frozen',
#   'Fish, raw, american, shad',
#   'Potatoes, as purchased, frozen, salt added in processing, steak fries, french fried',
#   'Rutabagas, with salt, drained, boiled, cooked',
#   'Gravy, powder, dry, mushroom',
#   "CAMPBELL'S Red and White, condensed, Creamy Chicken Noodle Soup",
#   'Plantains, Latino restaurant, fried, yellow',
#   'Egg, scrambled, cooked, whole',
#   'Tomatoes, no salt added, packed in tomato juice, canned, ripe, red',
#   'Beef, pastrami, cured',
#   'Bratwurst, cooked, veal',
#   'Corn flour, enriched, masa, yellow',
#   'ARCHWAY Home Style Cookies, Reduced Fat Ginger Snaps',
#   'Beef, raw, choice, trimmed to /" fat, separable lean and fat, composite of trimmed retail cuts',
#   'Pork, pan-broil, heated, separable lean and fat, bone-in, slice, ham, cured',
#   'Pork, raw, separable lean and fat, composite of trimmed retail cuts (leg, loin, shoulder, and spareribs), fresh',
#   'Fast Foods, Skin and breading from all pieces, Fried Chicken',
#   'Pork, reduced sodium, pan-fried or roasted, broiled, cooked, bacon, cured',
#   'Cereals, dry, Hearty Honey & Cinnamon, KASHI GO LEAN Hot Cereal',
#   'WORTHINGTON Vegetable Steaks, unprepared, canned',
#   'Snacks, with vitamin C, pieces, fruit leather',
#   'USDA Commodity peaches, drained, light syrup, canned',
#   'Candies, SNICKERS Bar, MARS SNACKFOOD US',
#   'Pork, raw, separable lean and fat, blade (steaks), (Boston butt), shoulder, fresh',
#   'Beverages, hard cider, AMBER',
#   'Ground turkey, raw',
#   'Bread, toasted, wheat germ',
#   "Beverages, KELLOGG'S SPECIAL K protein powder",
#   'Lamb, braised, cooked, separable lean only, square-cut shoulder chops, imported, New Zealand',
#   'Soup, prepared with water, mix, dry, cream of chicken',
#   'Beef, grilled, cooked, select, trimmed to " fat, separable lean only, boneless, top round steak, round',
#   'KEEBLER, Cheese & Peanut Butter Sandwich Crackers',
#   'Beverages, diet, decaffeinated, ready to drink, black, tea',
#   'Fish, dry heat (may have been previously frozen), cooked, Pacific, cod',
#   'English muffins, whole grain white',
#   'Lamb, broiled, cooked, trimmed to /" fat, separable lean and fat, boneless, sirloin chops, leg, fresh, imported, Australian',
#   'Brussels sprouts, with salt, drained, boiled, cooked, frozen',
#   'Tamarinds, raw',
#   'BURGER KING, Hamburger',
#   'Milk, % milkfat, fluid, producer',
#   'Chard, with salt, drained, boiled, cooked, swiss',
#   'Rice, raw, long-grain, brown',
#   'Beef, raw, choice, separable lean only, shortribs, rib',
#   'Beverages, Mango Peach, V SPLASH Juice Drinks',
#   'Pork, roasted, heated, separable lean only, bone-in, rump, ham with natural juices, cured',
#   'Rice, unenriched, cooked, medium-grain, white',
#   'SUNSHINE, Snack Mix, CHEEZ-IT',
#   'Candies, prepared-from-recipe, divinity',
#   'Edamame, prepared, frozen',
#   'ON THE BORDER, refried beans',
#   "WENDY'S, Chicken Nuggets",
#   'Pork, broiled, cooked, with added solution, separable lean and fat, boneless, top loin (chops), loin, fresh',
#   'Pork, raw, separable lean only, boneless, center rib (chops or roasts), loin, fresh',
#   'Beef, grilled, cooked, choice, trimmed to " fat, separable lean and fat, steak, tip center, knuckle, round',
#   'KEEBLER, Original Graham Cookies, Cheesecake Middles, FUDGE SHOPPE',
#   'Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand',
#   'Beverages, Whey protein powder isolate',
#   'Vanilla extract',
#   'Beans, with salt, boiled, cooked, mature seeds, small white',
#   'Beef, raw, choice, trimmed to /" fat, separable lean only, shank crosscuts',
#   'LOMA LINDA Low Fat Big Franks, unprepared, canned',
#   'Beef, fast fried, cooked, separable lean and fat, tenderloin, imported, New Zealand',
#   'Beef, roasted, cooked, all grades, trimmed to " fat, separable lean only, roast, bottom round, round',
#   'KFC, meat and skin with breading, Wing, EXTRA CRISPY, Fried Chicken',
#   'Stew/soup, caribou (Alaska Native)',
#   'Beverages,,Gerolsteiner naturally sparkling mineral water, GEROLSTEINER BRUNNEN GmbH & Co KG',
#   'Lamb, broiled, cooked, choice, trimmed to /" fat, separable lean only, loin, domestic',
#   'Lamb, raw, separable lean and fat, rack - partly frenched, imported, New Zealand',
#   "MORNINGSTAR FARMS Mushroom Lover's Burger, unprepared, frozen",
#   'Protein supplement, powder, Muscle Milk Light, milk based',
#   'Chicken, stewed, cooked, meat only, leg, broilers or fryers',
#   'Game meat, raw, beaver',
#   'Beef, raw, separable fat, retail cuts',
#   'Ice creams, vanilla, low carbohydrate, regular',
#   'Beef, braised, cooked, select, trimmed to " fat, separable lean only, steak, bottom round, round',
#   'Beef, raw, choice, trimmed to " fat, separable lean and fat, tri-tip roast, bottom sirloin',
#   'Lettuce, raw, iceberg (includes crisphead types)',
#   'Babyfood, toddler, beef lasagna, dinner',
#   'Babyfood, arrowroot, cookies',
#   'Lemons, without peel, raw',
#   'Beef, raw, all grades, trimmed to /" fat, separable lean only, lip-on, boneless, top loin steak, loin',
#   'Alcoholic beverage,  proof, rum, distilled',
#   'Tomato products, with herbs and cheese, sauce, canned',
#   'Gourd, with salt, drained, boiled, cooked, dishcloth (towelgourd)',
#   'Beef, grilled, cooked, select, trimmed to " fat, separable lean and fat, outside skirt, boneless, plate steak',
#   'MURRAY, Chocolate Chip Cookies, SOUTHERN KITCHEN',
#   'Nuts, without salt added, dry roasted, pistachio nuts',
#   'Ice creams, Vanilla, No Sugar Added, BREYERS',
#   'Fish, raw, tilefish',
#   "APPLEBEE'S, from kids' menu, chicken tenders",
#   'Beef, braised, cooked, select, trimmed to " fat, separable lean and fat, arm pot roast, chuck',
#   'Babyfood, toddler, dices, peaches',
#   'Grape leaves, canned',
#   'Soy flour, roasted, full-fat',
#   'Beverages, powder, Whiskey sour mix',
#   "Candies, HERSHEY'S POT OF GOLD Almond Bar",
#   'Soup, prepared with equal volume water, canned, tomato bisque',
#   'Pork, unheated, canned, extra lean (approximately % fat), ham, cured',
#   'Soy protein concentrate, produced by alcohol extraction',
#   'Fast foods, hot fudge, sundae',
#   'SUNSHINE, Cheez-It Mixx and Cheesy Pizza Crackers, GRIPZ',
#   'Crustaceans, moist heat, cooked, farmed, mixed species, crayfish',
#   'Miso',
#   'Ice creams, chocolate',
#   'Hummus, home prepared',
#   'Doughnuts, plain (includes unsugared, old-fashioned), cake-type',
#   'Chicken, heated (microwave), barbecue flavored, glazed, frozen, wing',
#   'Beverages, Classic Malt powder, OVALTINE',
#   'Snacks, corn, brown rice, rice cakes',
#   'Beef, raw, select, trimmed to " fat, separable lean only, boneless, top round roast, round',
#   'Currants, raw, red and white',
#   'Salad dressing, KRAFT MIRACLE WHIP FREE Nonfat Dressing',
#   'Turkey, simmered, cooked, all classes, liver',
#   'WORTHINGTON Chic-Ketts, unprepared, frozen',
#   'LOMA LINDA Redi-Burger, unprepared, canned',
#   'Pork, roasted, heated, separable lean and fat, bone-in, rump, ham -- water added, cured',
#   'Pork, raw, separable lean and fat, carcass, fresh',
#   'Oil, palm',
#   'Coffeecake, creme-filled with chocolate frosting',
#   'Babyfood, strained, noodles and chicken, vegetables, dinner',
#   'Crustaceans, raw, blue, crab',
#   'Orange juice, with added calcium, diluted with  volume water, unsweetened, frozen concentrate',
#   'Bagels, wheat',
#   'Cookies, lemon wafer, gluten-free',
#   "Gravy, au jus, CAMPBELL'S",
#   'Infant formula, ready-to-feed, ADVANCE with iron, ISOMIL, SIMILAC, ABBOTT NUTRITION',
#   'Alcoholic beverage, sweet, dessert, wine',
#   'Beverages, sweetened, ready-to-drink, green, tea',
#   'Rice bran, crude',
#   "SCHIFF,TIGER'S MILK BAR",
#   'Tomatoes, packed in tomato juice, canned, ripe, red',
#   'Pork, roasted, cooked, separable lean and fat, whole, shoulder, fresh',
#   'Beef, raw, choice, trimmed to " fat, separable lean and fat, inside skirt, boneless, plate steak',
#   'English muffins, with ca prop (includes sourdough), enriched, plain',
#   'Chicken, meat only, drumstick, BBQ, rotisserie, broiler',
#   'Cereals, dry, unenriched, farina',
#   'Cereals, without salt, prepared with water, instant, CREAM OF WHEAT',
#   'Beef, grilled, cooked, choice, trimmed to /" fat, separable lean only, boneless, top sirloin cap steak, loin',
#   'SPAGHETTIOS, Spaghetti in Tomato & Cheese Sauce',
#   'Cereals, without salt, cooked with water, enriched, regular and quick, yellow, corn grits',
#   'Beef, broiled, cooked, select, trimmed to " fat, separable lean and fat, steak, flank',
#   'Puddings, prepared with whole milk, regular, dry mix, banana',
#   'Sausage, reduced sodium, and beef, turkey, pork',
#   'Nuts, unblanched, dried, brazilnuts',
#   "Cereals ready-to-eat, Bite Size, Maple & Brown Sugar, FROSTED MINI-WHEATS, KELLOGG'S",
#   'Soymilk (All flavors), enhanced',
#   'Vitasoy USA Azumaya, Silken Tofu',
#   'Bread, toasted, (includes gluten), protein',
#   'Egg substitute, powder',
#   'Cookies, reduced fat, shortbread',
#   'Cauliflower, with salt, cooked, green',
#   'Sauce, CHA! BY TEXAS PETE, sriracha, hot chile',
#   "Cereals ready-to-eat, KELLOGG'S SPECIAL K Low Fat Granola, KELLOGG",
#   'Cookies, reduced fat, vanilla sandwich with creme filling',
#   'MURRAY, Coconut Bars Cookies, COOKIE JAR CLASSICS',
#   'Beverages, DANNON Fluoride To Go, non-carbonated, bottled, water',
#   'Oat bran, cooked',
#   'Pizza, cooked, frozen, thick crust, meat topping',
#   'Carrots, raw',
#   'Snacks, nacho cheese, made with olestra, low fat, tortilla chips',
#   'Fish, drained solids, without salt, canned in oil, light, tuna',
#   'Waffle, microwave, ready-to-heat, frozen, plain',
#   'Infant formula, with ARA and DHA, powder, For Spit Up, SIMILAC, ABBOTT NUTRITION',
#   'Cereals ready-to-eat, Regular, KRETSCHMER Wheat Germ, SUN COUNTRY',
#   'Beef, raw, select, trimmed to /" fat, separable lean and fat, composite of trimmed retail cuts',
#   'Wild rice, raw',
#   'Fish, smoked, cisco',
#   'Beef, roasted, cooked, choice, trimmed to " fat, separable lean and fat, roast, tip round, round',
#   'Babyfood, prepared with whole milk, with bananas, oatmeal, cereal',
#   'Snacks, salted, soy chips or crisps',
#   'MURRAY, Pecan Shortbread Cookies, SUGAR FREE',
#   'Squash, with salt, drained, boiled, cooked, frozen, includes skin, zucchini, summer',
#   'Taro, without salt, cooked, tahitian',
#   'SUNSHINE, Reduced Fat Crackers, CHEEZ-IT',
#   'TACO BELL, cheese and lettuce, Soft Taco with chicken',
#   'Tofu, prepared with calcium sulfate, dried-frozen (koyadofu)',
#   'Beans, low sodium, solids and liquids, canned, mature seeds, pinto',
#   'Fish, dry heat, cooked, white, sucker',
#   'GARDENBURGER Black Bean Chipotle Burger, unprepared, frozen',
#   'Yardlong bean, with salt, drained, boiled, cooked',
#   'Salad dressing, bacon and tomato',
#   'Pigeonpeas, without salt, drained, boiled, cooked, immature seeds',
#   'Soup, ready to serve, vegetable broth',
#   'Carbonated beverage, cream soda',
#   'Salami, % less sodium, sliced, dry, pork and beef, Italian',
#   'Fish, raw, cusk',
#   "Cereals ready-to-eat, little bites, KELLOGG'S FROSTED MINI-WHEATS, KELLOGG",
#   'Kanpyo, (dried gourd strips)',
#   'Beef, grilled, cooked, select, trimmed to /" fat, separable lean only, bone-in, t-bone steak, short loin',
#   'Infant formula, with ARA and DHA, not reconstituted, powder, with iron, PROSOBEE LIPIL, ENFAMIL, MEAD JOHNSON',
#   'Fish, breaded and fried, cooked, Atlantic, croaker',
#   'Cereals ready-to-eat, RALSTON TASTEEOS',
#   'Crackers, with cheese filling, sandwich, wheat',
#   'Corn, without salt, drained, boiled, kernels cut off cob, frozen, white, sweet',
#   'Beef, raw, all grades, trimmed to /" fat, separable lean and fat, steak, bottom round, round',
#   'Wheat flours, unenriched, bread',
#   'Beef, broiled, cooked, select, trimmed to /" fat, separable lean and fat, steak, top sirloin',
#   'Beef, grilled, cooked, all grades, trimmed to /" fat, separable lean only, boneless, top loin filet',
#   'Lamb, braised, cooked, separable lean and fat, square-cut shoulder chops, imported, New Zealand',
#   'Ground turkey, raw, % fat, % lean',
#   'Corn, dried (Navajo)',
#   'Potatoes, without salt, skin, cooked in skin, microwaved',
#   'Chicken, pan-browned, cooked, crumbles, ground',
#   'Cereals ready-to-eat, Honeycomb Cereal, POST',
#   'Pork, unheated, canned, extra lean and regular, ham, cured',
#   'Hyacinth-beans, with salt, drained, boiled, cooked, immature seeds',
#   'Bread, enriched (includes corn muffin mix), dry mix, cornbread',
#   'Alcoholic beverage, canned, pina colada',
#   'Lamb, grilled, cooked, trimmed to " fat, separable lean only, bone-in, denuded, frenched, rib chop, fresh, imported, Australian',
#   'Nuts, unblanched, honey roasted, almonds',
#   'GLUTINO, Chocolate Vanilla Creme, Gluten Free Cookies',
#   'Fish, tuna salad',
#   'Butterbur, raw, (fuki)',
#   'Beef, raw, choice, trimmed to " fat, separable lean only, boneless, shoulder pot roast or steak',
#   'Nuts, almond paste',
#   'Candies, CHUNKY Bar, NESTLE',
#   'Cereals ready-to-eat, TRIX, GENERAL MILLS',
#   'Turkey, skin and bone removed, cooked, smoked, light or dark meat',
#   'Beef, raw, select, trimmed to " fat, separable lean and fat, boneless, eye of round steak, round',
#   'Dessert topping, pressurized',
#   'Fast foods, meatball marinara on white bread, submarine sandwich',
#   'Salad dressing, light, blue or roquefort cheese dressing',
#   'Java-plum, raw, (jambolan)',
#   'Spices, coriander seed',
#   'Whale, dried (Alaska Native), meat, beluga',
#   'Spices, ground, savory',
#   'Cookies, regular, peanut butter sandwich',
#   'Breakfast tart, low fat',
#   'Broccoli, cooked, chinese',
#   'Beef, pan-browned, cooked, crumbles, % lean meat / % fat, ground',
#   "CAMPBELL'S CHUNKY Soups, Baked Potato with Steak & Cheese Soup",
#   'Pork, roasted, heated, separable lean and fat, bone-in, shank, ham, cured',
#   'BURGER KING, Vanilla Shake',
#   'Veal, braised, cooked, separable lean and fat, blade, shoulder',
#   'Soup, condensed, canned, bean with frankfurters',
#   'Beef, raw, choice, trimmed to " fat, separable lean only, boneless, chuck eye steak',
#   'Pork, microwaved, cooked, bacon, cured',
#   'Beans, with salt, boiled, cooked, mature seeds, pinto',
#   'Beef, braised, cooked, pancreas, variety meats and by-products',
#   'Sweet potato, unprepared, frozen',
#   'Lamb, cooked, trimmed to /" fat, separable lean and fat, composite of trimmed retail cuts, fresh, imported, Australian',
#   'Bread, made with tapioca starch and brown rice flour, white, gluten-free',
#   'Babyfood, fruit filling, fortified cereal bar',
#   'Bagels, whole grain white',
#   'Goose, roasted, cooked, meat and skin, domesticated',
#   'Pork, raw, separable lean and fat, composite of trimmed retail cuts (loin and shoulder blade), fresh',
#   'Rice, cooked, enriched, regular, long-grain, white',
#   'KEEBLER, Simply Shortbread Cookies, SANDIES',
#   'Yambean (jicama), without salt, drained, boiled, cooked',
#   'MURRAY, JACKS Vanilla Wafers',
#   'Infant formula, powder, PROTECT PLUS, GOOD START , GERBER',
#   "Cereals ready-to-eat, KELLOGG'S COCOA KRISPIES, KELLOGG",
#   'Chicken, roasted, cooked, meat and skin, cornish game hens',
#   'MURRAY, Oatmeal Cookies, SOUTHERN KITCHEN',
#   "CAMPBELL'S Red and White, condensed, Chicken Barley with Mushrooms Soup",
#   'Rice cake, cracker (include hain mini rice cakes)',
#   'Corn dogs, prepared, frozen',
#   'Tofu, prepared with nigari, extra firm',
#   'Chicken, not reheated, frozen, precooked, dark and white meat, nuggets',
#   'Cheese spread, American, pasteurized process',
#   'Cereals ready-to-eat, QUAKER Honey Graham LIFE Cereal, QUAKER',
#   'Cereals, dry, dates and walnuts, raisins, Instant Oatmeal, QUAKER',
#   'Cherries, solids and liquids, light syrup pack, canned, red, sour',
#   'Soup, prepared with equal volume water, canned, turkey vegetable',
#   'Milk, calcium reduced, nonfat, dry',
#   'Spinach, raw',
#   'Carbonated beverage, chocolate-flavored soda',
#   'Cereals ready-to-eat, strawberry, Yogurt Burst, CHEERIOS, GENERAL MILLS',
#   "Gravy, fat free, chicken, CAMPBELL'S",
#   'Beef, grilled, cooked, all grades, trimmed to " fat, separable lean and fat, outside skirt, boneless, plate steak',
#   'Candies, WHATCHAMACALLIT Candy Bar',
#   "MOTHER'S, Taffy Sandwich Cookies",
#   'Yeast extract spread',
#   'Cornmeal, enriched, plain, bolted, self-rising, yellow',
#   'Beef, raw, choice, trimmed to /" fat, separable lean and fat, lip-on, bone-in, rib eye steak/roast',
#   'SWANSON, Chicken A La King',
#   'Beef, braised, cooked, separable lean only, flank, imported, New Zealand',
#   'Chicken, raw, meat and skin, neck, broilers or fryers',
#   "MOTHER'S, Iced Oatmeal Cookies",
#   'Fast foods, with beans and cheese, burrito',
#   'Beef, raw, select, trimmed to " fat, separable lean and fat, steak, top blade, shoulder clod, chuck',
#   'HUNGRY MAN, unprepared, frozen, Salisbury Steak With Gravy',
#   'Turkey, roasted, with added solution, meat only, from whole bird, back',
#   'Rice, dry, enriched, parboiled, long-grain, white',
#   'Sausage, pork, beef, chicken, canned, Vienna',
#   'Cereals ready-to-eat, plain, QUAKER OAT LIFE, QUAKER',
#   'Beverages, prepared with water, unsweetened, instant, tea',
#   'Grapefruit, solids and liquids, light syrup pack, canned, sections',
#   'Snacks, salted, wheat-based, sesame sticks',
#   "WENDY'S, with cheese, Double Stack",
#   "BURGER KING, CROISSAN'WICH with Sausage and Cheese",
#   'Drumstick leaves, with salt, drained, boiled, cooked',
#   'Salami, turkey, cooked',
#   'Beef, braised, cooked, select, trimmed to " fat, separable lean and fat, top round, round',
#   'Beef, raw, all grades, trimmed to /" fat, separable lean only, flat half, brisket',
#   'Alcoholic beverage, dry, dessert, wine',
#   'Beef, grilled, cooked, select, trimmed to /" fat, separable lean and fat, lip-on, boneless, top loin steak, loin',
#   'Beef, raw, choice, trimmed to /" fat, separable lean only, steak, top sirloin',
#   'Mollusks, drained solids, canned, mixed species, clam',
#   'Chicken, thigh meat and skin, BBQ, rotisserie, broiler',
#   'Restaurant, assorted, egg rolls, Chinese',
#   'Cereals ready-to-eat, ORGANIC PROMISE Autumn Wheat, KASHI',
#   'PREGO Pasta, ready-to-serve, Chunky Garden Mushroom Supreme Italian Sauce',
#   'Salad dressing, regular, commercial, italian dressing',
#   'Bagels, oat bran',
#   'Peanuts, raw, virginia',
#   'Lamb, raw, separable lean only, loin chop, imported, New Zealand',
#   'Nuts, blanched, hazelnuts or filberts',
#   'Cheese, whole milk, ricotta',
#   'Spaghetti, canned, with meatballs in tomato sauce',
#   'Crackers, regular, standard snack-type',
#   'Margarine-like, with added vitamin D, without salt, stick/tub/bottle, % fat, vegetable oil spread',
#   'Beef, raw, choice, trimmed to " fat, separable lean only, boneless, under blade pot roast or steak, chuck',
#   'Ice creams, soft-serve, light, vanilla',
#   'Beef, raw, choice, trimmed to " fat, separable lean and fat, roast, tip round, round',
#   'Fish, dry heat, cooked, sheepshead',
#   'Beef, raw, separable lean only, cube roll, imported, New Zealand',
#   'Beef, raw, choice, trimmed to /" fat, separable lean and fat, steak, top sirloin',
#   'Onion rings, heated in oven, prepared, frozen, par fried, breaded',
#   'Pumpkin, raw',
#   'Alcoholic beverage,  proof, vodka, distilled',
#   'Sweet Potatoes, unprepared, frozen, crosscut, french fried',
#   'Milk, with added vitamin A and vitamin D, nonfat, evaporated, canned',
#   "Cereals ready-to-eat, KELLOGG'S FROOT LOOPS, KELLOGG",
#   'Stew, badufsuki (Hopi), pinto bean and hominy',
#   'Beef, grilled, cooked, all grades, trimmed to " fat, separable lean only, boneless, shoulder steak',
#   'Infant Formula, prepared from powder, with iron, ENFAMIL GENTLEASE LIPIL, MEAD JOHNSON',
#   'Muffins, oat bran',
#   "CAMPBELL'S, condensed, Homestyle Chicken Noodle Soup",
#   'Pork loin, lean only, raw, bone-in, backribs, fresh',
#   'Beans, solids and liquids, canned, mature seeds, pinto',
#   'Cereals, salt, prepared with water, QUAKER MultiGrain Oatmeal, QUAKER',
#   'Fish, raw, ocean, pout',
#   'Waffle, microwaved, ready-to-heat, frozen, buttermilk',
#   'Shortening, soybean (hydrogenated) and palm (hydrogenated), multipurpose',
#   'Oil, uses similar to  degree hard butter, confection fat, palm kernel (hydrogenated), industrial',
#   'OLIVE GARDEN, chicken parmigiana without pasta',
#   'Spices, curry powder',
#   'Cereals ready-to-eat, ALPHA-BITS, POST',
#   'Potatoes, as purchased, frozen, salt not added in processing, all types, french fried',
#   'Candies, PAYDAY Bar, HERSHEYS',
#   'SCHAR, Classic White Bread, Wheat-Free, Gluten-Free',
#   'Lamb, raw, trimmed to /" fat, separable lean and fat, whole (shank and sirloin), leg, frozen, imported, New Zealand',
#   'Soybeans, stir-fried, cooked, sprouted, mature seeds',
#   'Babyfood, mixed fruit juice with low fat yogurt',
#   'Squash, canned, italian style, zucchini, summer',
#   'Beef, grilled, cooked, select, trimmed to /" fat, separable lean and fat, lip-on, bone-in, rib eye steak',
#   'Beverages, Diet Fruit Medley, V SPLASH Juice Drinks',
#   'Lamb, broiled, cooked, ground',
#   'Crackers, without salt, plain, melba toast',
#   'Beverages, mineral bottled water, naturally sparkling, GEROLSTEINER BRUNNEN GmbH & Co KG (Gerolsteiner)',
#   'Rice, enriched, raw, medium-grain, white',
#   'Beef, raw, separable lean only, boneless, ribeye steak/roast lip-on, rib, grass-fed, imported, Australian',
#   'Seeds, dried, whole, sesame seeds',
#   "MORNINGSTAR FARMS Sesame Chik'n Entree, unprepared, frozen",
#   'Snacks, very low sodium, corn cakes',
#   'Milk, with added vitamin D, whole, dry',
#   'Beef, broiled, cooked, choice, trimmed to " fat, separable lean only, t-bone steak, short loin',
#   'Beef, roasted, cooked, select, trimmed to " fat, separable lean only, boneless, eye of round roast, round',
#   'Rice, unenriched, raw, regular, long-grain, white',
#   'Wasabi, raw, root',
#   'Cheese, low sodium, parmesan',
#   'Snacks, buckwheat, brown rice, rice cakes',
#   'Pimento, canned',
#   'Fish, dry heat, cooked, rainbow, smelt',
#   'Veal, braised, cooked, tongue, variety meats and by-products',
#   'Candies, DOVE Milk Chocolate, MARS SNACKFOOD US',
#   'Beef, roasted, cooked, prime, trimmed to /" fat, separable lean and fat, whole (ribs -), rib',
#   'Pork, roasted, cooked, separable lean and fat, bone-in, blade (roasts), loin, fresh',
#   'Chicken, flour, fried, cooked, meat and skin, breast, broilers or fryers',
#   'OSCAR MAYER, Wieners (beef franks)',
#   'POPEYES, analyzed , Spicy Chicken Strips',
#   'SUPPER BAKES MEAL KITS, Cheesy Chicken with pasta (chicken not included)',
#   'Lamb, soaked and simmered, cooked, heart, imported, New Zealand',
#   'POPEYES, biscuit',
#   'Cherries, solids and liquids, light syrup pack, canned, sweet',
#   'Fish, with skin (Alaska Native), raw, halibut',
#   'Oil, used for whipped toppings and coffee whiteners, coconut (hydrogenated), industrial',
#   'Broccoli, raw, flower clusters',
#   'Babyfood, strained, carrots and beef',
#   'Veal, raw, separable lean and fat, blade chop, shoulder',
#   "McDONALD'S, QUARTER POUNDER with Cheese",
#   "Cereals ready-to-eat, SPECIAL K Vanilla Almond, KELLOGG'S",
#   'Cereals ready-to-eat, Multi-Grain CHEERIOS, GENERAL MILLS',
#   'Fast foods, and ranch sauce, cheese, with lettuce, grilled chicken in tortilla',
#   'USDA Commodity, cooked, frozen, ground bulk/coarse ground, beef',
#   'KEEBLER, Triple Fudge Filled Cookies, FUDGE SHOPPE',
#   'TACO BELL, Soft Taco with steak',
#   'Beef, grilled, cooked, select, trimmed to " fat, separable lean and fat, boneless, tenderloin steak, loin',
#   'Beef, grilled, cooked, choice, trimmed to " fat, separable lean only, boneless, eye of round steak, round',
#   'Mushrooms, microwaved, white',
#   'Babyfood, prepared with whole milk, with honey, oatmeal, cereal',
#   'Margarine, with salt, stick, composite, % fat, regular',
#   'Turkey, roasted, cooked, meat only, drumstick, retail parts',
#   'Cereals ready-to-eat, RAISIN VINEYARD, KASHI ORGANIC PROMISE',
#   'Fast Foods, meat and skin with breading, Drumstick, Fried Chicken',
#   'Tomatoes, year round average, raw, ripe, red',
#   'Candies, milk chocolate covered, MILKY WAY Caramels, MARS SNACKFOOD US',
#   'Soup, dry, cubed, beef broth',
#   'Lamb, raw, kidney, imported, New Zealand',
#   'Rolls, wheat, dinner',
#   'Veal, braised, cooked, separable lean and fat, boneless, plate half, breast',
#   'Beef, broiled, cooked, prime, trimmed to /" fat, separable lean and fat, top loin, short loin',
#   'Beef, raw, choice, trimmed to /" fat, separable lean only, porterhouse steak, short loin',
#   'Beef, boiled, cooked, heart, variety meats and by-products, imported, New Zealand',
#   'Snacks, shrimp cracker',
#   'Hush puppies, prepared from recipe',
#   'Vegetable juice, DAILY GREENS, BOLTHOUSE FARMS',
#   'Cereals, without salt, cooked with water, enriched, regular and quick, white, corn grits',
#   'Beef, raw, choice, trimmed to /" fat, separable lean and fat, boneless, top sirloin cap steak, loin',
#   'Syrups, cane and % maple, table blends',
#   'Bologna, turkey and beef, pork',
#   'Cake, fat-free, commercially prepared, pound',
#   'Beverages, unsweetened, rice milk',
#   'Beef, grilled, cooked, select, trimmed to /" fat, separable lean only, steak, top loin, short loin',
#   'Soybeans, without salt, boiled, mature cooked',
#   "KELLOGG'S, Homestyle, Waffles, EGGO",
#   'Spelt, uncooked',
#   'Beef, broiled, cooked, select, trimmed to " fat, separable lean and fat, top blade, chuck',
#   'Beef, raw, select, trimmed to /" fat, separable lean only, arm pot roast, chuck',
#   'Cereals ready-to-eat, Fruity CHEERIOS, GENERAL MILLS',
#   'Snacks, almond, hard, granola bars',
#   'Beef, braised, cooked, separable lean only, hind shin, imported, New Zealand',
#   'Fast foods, breaded and fried, shrimp',
#   'Beef, roasted, cooked, choice, trimmed to /" fat, separable lean and fat, roast, bottom round, round',
#   'Seeds, dried, pumpkin and squash seed kernels',
#   'Pastry, Pastelitos de Guava (guava pastries)',
#   'Corn, without salt, drained, boiled, cooked, kernels on cob, frozen, yellow, sweet',
#   'Beef, broiled, cooked, prime, trimmed to /" fat, separable lean and fat, small end (ribs -), rib',
#   'Lentils, without salt, stir-fried, cooked, sprouted',
#   'Beef, raw, Aust marble score , separable lean and fat, top loin steak/roast, loin, Wagyu, imported, Australian',
#   'Chicken, braised, cooked, with added solution, meat only, boneless, skinless, breast, broiler or fryers',
#   "Cereals ready-to-eat, Organic FLAX PLUS flakes, NATURE'S PATH",
#   'Pork, raw, separable lean only, boneless, center loin (chops), loin, fresh',
#   'Cereals ready-to-eat, BASIC , GENERAL MILLS',
#   'OSCAR MAYER, Braunschweiger Liver Sausage (sliced)',
#   'Rolls, and corn starch, rice starch, made with rice flour, white, gluten-free',
#   'Fish, raw, freshwater, drum',
#   'Beef, braised, cooked, all grades, trimmed to " fat, separable lean and fat, blade roast, chuck',
#   'Nuts, roasted, japanese, chestnuts',
#   'Beans, with salt, boiled, cooked, mature seeds, navy',
#   'Infant formula, with ARA and DHA, ready-to-feed, AR LIPIL, ENFAMIL, MEAD JOHNSON',
#   'Beef, braised, cooked, separable lean only, brisket navel end, imported, New Zealand',
#   'Cheese, no sodium added, % milkfat, lowfat, cottage',
#   'Frankfurter, heated, meat',
#   'Onions, tops only, young green',
#   'Chicken, raw, skin only, broilers or fryers',
#   'KEEBLER, Pecan Shortbread Cookies, SANDIES',
#   'Corn, without salt, drained, boiled, cooked, yellow, sweet',
#   'Beverages, with whitener and low calorie sweetener, decaffeinated, instant, coffee and cocoa',
#   'Soymilk, vitamins A and D, with added calcium, original and vanilla',
#   'Couscous, cooked',
#   'Spices, red or cayenne, pepper',
#   'Pumpkin leaves, with salt, drained, boiled, cooked',
#   'Infant Formula, powder, GENTLEASE, ENFAMIL, MEAD JOHNSON',
#   'Danish pastry, unenriched, cinnamon',
#   'Seal, raw (Alaska Native), meat, bearded (Oogruk)',
#   'Squash, without salt, drained, boiled, cooked, frozen, includes skin, zucchini, summer',
#   'Lamb, broiled, cooked, trimmed to /" fat, separable lean only, bone-in, center slice, leg, fresh, imported, Australian',
#   "CAMPBELL'S Homestyle Mexican Style Chicken Tortilla Soup",
#   'Pork, raw, separable lean and fat, bone-in, blade (chops or roasts), loin, fresh',
#   'Chicken, stewed, cooked, meat and skin, light meat, broilers or fryers',
#   'Fennel, raw, bulb',
#   'Eggnog',
#   'Soybeans, no salt added, roasted, mature seeds',
#   'Beef, roasted, cooked, choice, trimmed to " fat, separable lean and fat, boneless, eye of round roast, round',
#   'Game meat, raw, squirrel',
#   'Potatoes, without salt, flesh and skin, cooked in skin, microwaved',
#   'Puddings, prepared with % milk, regular, dry mix, chocolate',
#   'Beef, braised, cooked, choice, trimmed to " fat, separable lean only, steak, flank',
#   'Lamb, raw,   trimmed to /" fat, separable lean only, whole (arm and blade), shoulder, fresh, imported, Australian',
#   'Beerwurst, pork and beef, beer salami',
#   'Stew, moose (Alaska Native)',
#   'Fish, dry heat, cooked, king, mackerel',
#   'Turkey, raw, with added solution, meat only, breast, retail parts',
#   'Cheese, fat-free, cheddar or American, pasteurized process',
#   'Pears, solids and liquids, juice pack, canned',
#   'Fish, Pacific (Alaska Native), herring eggs on giant kelp',
#   "KRAFT FOODS, dry, Coating for Pork, SHAKE 'N' BAKE ORIGINAL RECIPE",
#   'KEEBLER, Minis Original Crackers, CLUB',
#   'Lamb, raw, trimmed to /" fat, separable lean and fat, boneless, sirloin chops, leg, fresh, imported, Australian',
#   'Turkey, roasted, with added solution, meat only, from whole bird, drumstick',
#   "KELLOGG'S, Egg & Cheese, Biscuit Scramblers, EGGO",
#   'Cheese, queso blanco, white',
#   'Snacks, CHEWY TRAIL MIX, NATURE VALLEY, GENERAL MILLS, granola bar',
#   'Kale, with salt, drained, boiled, cooked',
#   'Pie, commercially prepared, blueberry',
#   'Potatoes, unprepared, plain, frozen, hash brown',
#   'Lamb, raw, trimmed to /" fat, separable lean only, loin, fresh, imported, Australian',
#   'PIZZA HUT " Sausage Pizza, THIN \'N CRISPY Crust',
#   'Cauliflower, unprepared, frozen',
#   'Papaya, drained, heavy syrup, canned',
#   'Asparagus, drained, boiled, cooked',
#   'Beverages, Hot Cocoa Mix Rich Chocolate With Marshmallows, NESTLE, Cocoa mix',
#   'Pork, broiled, cooked, separable lean only, whole, loin, fresh',
#   'Sweet Potatoes, salt added in processing, frozen as packaged, french fried',
#   'Sauce, prepared from recipe, sofrito',
#   'Oil, intermediate grade product, confection fat, palm kernel (hydrogenated), industrial',
#   'Restaurant, spanish rice, Mexican',
#   'Mushrooms, drained solids, canned',
#   'Peanut butter, reduced sodium',
#   "McDONALD'S, Chicken McNUGGETS",
#   'Salad dressing, reduced fat, thousand island dressing',
#   'Cereals, dry, instant, CREAM OF WHEAT',
#   'Ground turkey, pan-broiled crumbles, % fat, % lean',
#   'Salad dressing, soybean without cholesterol, imitation, mayonnaise',
#   "McDONALD'S, Bacon Ranch Salad with Grilled Chicken",
#   'Swamp cabbage (skunk  cabbage), without salt, drained, boiled, cooked',
#   'Candies, prepared-from-recipe, fondant',
#   'Fast foods, tomato and sweet onion sauce, sweet onion chicken teriyaki on white bread with lettuce, submarine sandwich',
#   'Cheese, port de salut',
#   'Crackers, multigrain',
#   "Candies, POP'ABLES  MUSKETEERS Brand Bite Size Candies, MARS SNACKFOOD US",
#   'Yogurt, with low calorie sweetener, lowfat, fruit',
#   'Spaghetti, enriched (n x ), cooked, protein-fortified',
#   'Whale, skin and subcutaneous fat (muktuk) (Alaska Native), bowhead',
#   "Candies, REESE'S Peanut Butter Cups",
#   'Milk, with added nonfat milk solids and vitamin A and vitamin D, % milkfat, fluid, reduced fat',
#   'PEPPERIDGE FARM, Whole Grain Oatmeal Bread',
#   'Emu, broiled, cooked, top loin',
#   'Ostrich, cooked, top loin',
#   "Toaster Pastries, Frosted cherry, KELLOGG'S POP TARTS, KELLOGG",
#   'Beans, with salt, drained, boiled, cooked, sprouted, mature seeds, pinto',
#   'Huckleberries, raw (Alaska Native)',
#   'Lima beans, without salt, boiled, cooked, mature seeds, large',
#   'Beef, braised, cooked, all grades, trimmed to " fat, separable lean only, boneless, short ribs, chuck',
#   'HOUSE FOODS Premium Firm Tofu',
#   'Cereals, dry, quick, white, hominy grits, QUAKER',
#   'Cereals ready-to-eat, Caramel Delight, FIBER ONE, GENERAL MILLS',
#   "CAMPBELL'S CHUNKY Microwavable Bowls, ready-to-serve, Old Fashioned Vegetable Beef Soup",
#   'Lamb, raw, trimmed to /" fat, separable lean and fat, bone-in, center slice, leg, fresh, imported, Australian',
#   'Lamb, raw, trimmed to /" fat, separable lean only, bone-in, center slice, leg, fresh, imported, Australian',
#   "Snacks, fruit, NUTRI-GRAIN Cereal Bars, KELLOGG'S",
#   'Nuts, raw, cashew nuts',
#   'KASHI, Frozen Entree, Southwest Style Chicken',
#   'Beef, raw, select, trimmed to /" fat, separable lean and fat, top loin, loin',
#   'Alcoholic Beverage, Cabernet Sauvignon, red, table, wine',
#   'Babyfood, sweet potatoes strained, vegetables',
#   'Cereals ready-to-eat, cinnamon, Oatmeal Squares, QUAKER',
#   'Beverages, canned, orange and apricot juice drink',
#   'Shortening, fractionated palm, confectionery',
#   'Game meat, raw, elk',
#   'Pork, raw, separable lean and fat, whole, loin, fresh',
#   'Cookies, plain, commercially prepared, shortbread',
#   "Gravy, brown with onions, CAMPBELL'S",
#   'Infant formula, with ARA and DHA, powder, with iron, ENFACARE LIPIL, ENFAMIL, MEAD JOHNSON',
#   'Chicken, raw, meat only, broilers or fryers',
#   'Lima beans, solids and liquids, no salt added, canned, immature seeds',
#   'Beef, raw, all grades, trimmed to " fat, separable lean and fat, lip off, boneless, rib eye steak',
#   'Salsify, raw, (vegetable oyster)',
#   'KEEBLER, Reduced Fat, / Dipped, Fudge Grahams, FUDGE SHOPPE',
#   'Chicken, raw, meat and skin, breast, broilers or fryers',
#   "Dip, original flavor, bean, FRITO'S",
#   'Cheese, low fat, muenster',
#   'Soup, condensed, canned, tomato rice',
#   'ARCHWAY Home Style Cookies, Strawberry Filled',
#   'Waxgourd, with salt, drained, boiled, cooked, (chinese preserving melon)',
#   'Candies, sugar-coated almonds',
#   'Chicken, stewed, cooked, meat and skin, broilers or fryers',
#   'Radishes, dried, oriental',
#   'Gelatin desserts, prepared with water, dry mix',
#   'Meat extender',
#   'Chicken, raw, meat only, boneless, skinless, breast, broiler or fryers',
#   'Cowpeas, with salt, boiled, cooked, mature seeds, common (blackeyes, crowder, southern)',
#   'Snacks, ranch-flavor, tortilla chips',
#   'Baking chocolate, liquid, unsweetened',
#   'Beef, raw, all grades, trimmed to /" fat, separable lean only, boneless, top loin petite roast/filet',
#   'Beef macaroni with tomato sauce, reduced fat, frozen entree',
#   'Cereals ready-to-eat, homemade, granola',
#   'Cookies, baked, refrigerated dough, chocolate chip',
#   'Beef, grilled, cooked, select, trimmed to " fat, separable lean and fat, inside skirt, boneless, plate steak',
#   'Lamb, roasted, cooked, trimmed to /" fat, separable lean and fat, bone-in, trotter off, leg, fresh, imported, Australian',
#   "KELLOGG'S, Chocolate Chip, FIBERPLUS Waffles, EGGO",
#   'Potatoes, as purchased, frozen, salt added in processing, crinkle or regular cut, french fried',
#   'Restaurant, chili with meat and beans, family style',
#   'Balsam-pear (bitter gourd), without salt, drained, boiled, cooked, pods',
#   'Fungi, dried, Cloud ears',
#   'Waterchestnuts, raw, (matai), chinese',
#   "Sauce, original, BULL'S-EYE, barbecue",
#   'Turkey, roasted, cooked, meat and skin, whole',
#   'Beef, raw, prime, trimmed to /" fat, separable lean and fat, large end (ribs -), rib',
#   'Carrots, drained solids, regular pack, canned',
#   'Mollusks, dry heat, cooked, wild, eastern, oyster',
#   'Ham, minced',
#   'Ice cream sundae cone',
#   'CONTINENTAL MILLS, dry, Artificially Flavored, KRUSTEAZ Almond Poppyseed Muffin Mix',
#   'Beef, grilled, cooked, select, trimmed to /" fat, separable lean only, porterhouse steak, short loin',
#   'Barley, hulled',
#   'Beef, grilled, cooked, all grades, trimmed to " fat, separable lean and fat, boneless, chuck eye steak',
#   'Soup, commercial, condensed, canned, broccoli cheese',
#   'Grapes, solids and liquids, water pack, thompson seedless, canned',
#   'Lasagna, unprepared, frozen, cheese',
#   'Semolina, unenriched',
#   'Sandwich spread, beef, pork',
#   'Nuts, dried, pilinuts',
#   'Snacks, traditional flavor, CHEX MIX, GENERAL MILLS',
#   'Artichokes, without salt, drained, boiled, cooked, frozen, (globe or french)',
#   'Squash, unprepared, frozen, butternut, winter',
#   'Bread, cracked-wheat',
#   'Game meat, roasted, cooked, antelope',
#   'Cherimoya, raw',
#   'Beef, braised, cooked, all grades, trimmed to /" fat, separable lean and fat, whole, brisket',
#   'Pork, unheated, separable lean and fat, bone-in, slice, ham and water product, cured',
#   'Cream, light whipping, fluid',
#   'Rice, prepared, enriched, precooked or instant, long-grain, white',
#   'Fish oil, fully hydrogenated, menhaden',
#   'Beef, broiled, cooked, all grades, trimmed to /" fat, separable lean and fat, whole (ribs -), rib',
#   'Alcoholic beverage,  proof, coffee, liqueur',
#   'Mung beans, without salt, boiled, cooked, mature seeds',
#   'Fast foods, and bacon, cheese, with egg, croissant',
#   'Falafel, home-prepared',
#   'Nuts, raw, ginkgo nuts',
#   "KELLOGG'S, Ice Cream Shoppe Frosted Ice Creme Sandwich Toaster Pastries, POP-TARTS",
#   'Salad dressing, regular, green goddess',
#   'Rice, cooked, medium-grain, brown',
#   'Egg, pasteurized, sugared, frozen, raw, yolk',
#   'Roselle, raw',
#   'Cereals ready-to-eat, RALSTON Corn Flakes',
#   'Snacks, unsalted, plain, potato chips',
#   'Asparagus, with salt, drained, boiled, cooked',
#   'Chicken, braised, cooked, with added solution, meat and skin, thigh, dark meat',
#   'Sweeteners, liquid, fructose, tabletop',
#   'Beef, grilled, cooked, all grades, trimmed to " fat, separable lean and fat, steak, bottom round, outside round, round',
#   'Fast foods, with egg, biscuit',
#   'Potatoes, with salt, skin only, baked',
#   'Fruit salad, solids and liquids, juice pack, canned, (peach and pear and apricot and pineapple and cherry)',
#   'Beef, grilled, cooked, select, trimmed to " fat, separable lean and fat, lip off, boneless, rib eye steak',
#   'Veal, braised, cooked, brain, variety meats and by-products',
#   'Beverages, assorted fruit flavors, sweetened, bottles, Water with added vitamins and minerals',
#   'Babyfood, multigrain cereal and added iron fortified, with fruit, whole milk, yogurt',
#   'Beef, roasted, cooked, choice, trimmed to " fat, separable lean only, America\'s Beef Roast, boneless, chuck eye roast',
#   'Seasoning mix, coriander & annatto, sazon, dry',
#   'Pie, enriched flour, commercially prepared, apple',
#   'Cream substitute, powdered',
#   'Vegetarian fillets',
#   'Waxgourd, raw, (chinese preserving melon)',
#   'Chicken, breast meat and skin, BBQ, rotisserie, broiler',
#   'Salad dressing, regular, commercial, french dressing',
#   'Salami, pork, Italian',
#   'Noodles, dry, somen, japanese',
#   'PEPPERIDGE FARM, Parmesan, Baked Snack Crackers, Goldfish',
#   'Snacks, unsalted, made with enriched flour, plain, hard, pretzels',
#   'Beef, raw, select, trimmed to /" fat, separable lean only, steak, top loin, short loin',
#   'Pork, broiled, cooked, separable lean only, boneless, center rib (chops), loin, fresh',
#   'Pork, broiled, cooked, separable lean only, bone-in, sirloin (chops), loin, fresh',
#   'Macaroni, cooked, enriched, vegetable',
#   'Soup, prepared with equal volume water, canned, minestrone',
#   'Beef, raw, separable lean and fat, flank, imported, New Zealand',
#   'Frankfurter, turkey',
#   'SUNSHINE, Scrabble Jr Crackers, CHEEZ-IT',
#   'Oil, low linolenic, soy, industrial',
#   'Spices, ground, mace',
#   'Nuts, pecans',
#   'Oil, salad or cooking, cottonseed',
#   'Beef, broiled, cooked, choice, trimmed to /" fat, separable lean only, steak, top round, round',
#   'Game meat, stewed, cooked, composite of cuts, domesticated, rabbit',
#   'Fish, dry heat, cooked, florida, pompano',
#   'PACE, Organic Picante Sauce',
#   "Toaster Pastries, Frosted brown sugar cinnamon, KELLOGG'S POP TARTS, KELLOGG",
#   'Beans, without salt, drained, boiled, cooked, sprouted, mature seeds, kidney',
#   'Canada Goose, raw, skinless, breast meat',
#   'Sugars, maple',
#   'Beef, braised, cooked, choice, trimmed to /" fat, separable lean only, steak, bottom round, round',
#   'Poultry salad sandwich spread',
#   'Lettuce, raw, red leaf',
#   'Cereals, dry, regular, white, hominy grits, QUAKER',
#   'Puddings, prepared with whole milk, instant, dry mix, coconut cream',
#   'Beef, raw, select, trimmed to " fat, separable lean only, boneless, tenderloin roast, loin',
#   'Pork, roasted, heated, separable lean and fat, bone-in, rump, ham and water product, cured',
#   'Beverages, vitamin A and vitamin D,  added calcium, Ready-to-drink, flavored and sweetened, reduced fat, milk beverage',
#   'Formulated Bar, SOUTH BEACH protein bar',
#   'Fish, dry heat, cooked, chinook, salmon',
#   'Yardlong beans, raw, mature seeds',
#   'Milk and cereal bar',
#   "CAMPBELL'S, condensed, Vegetable Beef Soup",
#   'Kale, without salt, drained, boiled, cooked, frozen',
#   'Peppers, without salt, drained, boiled, cooked, green, sweet',
#   'CRACKER BARREL, coleslaw',
#   "Cereals ready-to-eat, KELLOGG'S SPECIAL K Chocolatey Strawberry, KELLOGG",
#   'Pork, simmered, cooked, frozen, ears, variety meats and by-products, fresh',
#   'Beans, raw, mature seeds, black turtle',
#   'Mollusks, moist heat, cooked, unspecified, whelk',
#   ...},
#  'serving_size': {'g'},
#  'calories': {'numeric'},
#  'total_fat': {'g'},
#  'saturated_fat': {'g', 'nan'},
#  'cholesterol': {'mg', 'numeric'},
#  'sodium': {'mg', 'numeric'},
#  'choline': {'mg', 'numeric'},
#  'folate': {'mcg', 'numeric'},
#  'folic_acid': {'mcg', 'numeric'},
#  'niacin': {'mg', 'numeric'},
#  'pantothenic_acid': {'mg', 'numeric'},
#  'riboflavin': {'mg', 'numeric'},
#  'thiamin': {'mg', 'numeric'},
#  'vitamin_a': {'IU', 'mcg', 'numeric'},
#  'vitamin_a_rae': {'mcg', 'numeric'},
#  'carotene_alpha': {'mcg', 'numeric'},
#  'carotene_beta': {'mcg', 'numeric'},
#  'cryptoxanthin_beta': {'mcg', 'numeric'},
#  'lutein_zeaxanthin': {'mcg', 'numeric'},
#  'lucopene': {'numeric'},
#  'vitamin_b12': {'mcg', 'numeric'},
#  'vitamin_b6': {'mg', 'numeric'},
#  'vitamin_c': {'mg', 'numeric'},
#  'vitamin_d': {'IU', 'numeric'},
#  'vitamin_e': {'mg', 'numeric'},
#  'tocopherol_alpha': {'mg', 'numeric'},
#  'vitamin_k': {'mcg', 'numeric'},
#  'calcium': {'mg', 'numeric'},
#  'copper': {'mg', 'numeric'},
#  'irom': {'mg', 'numeric'},
#  'magnesium': {'mg', 'numeric'},
#  'manganese': {'mg', 'numeric'},
#  'phosphorous': {'mg', 'numeric'},
#  'potassium': {'mg', 'numeric'},
#  'selenium': {'mcg', 'numeric'},
#  'zink': {'mg', 'numeric'},
#  'protein': {'g'},
#  'alanine': {'g', 'numeric'},
#  'arginine': {'g', 'numeric'},
#  'aspartic_acid': {'g', 'numeric'},
#  'cystine': {'g', 'numeric'},
#  'glutamic_acid': {'g', 'numeric'},
#  'glycine': {'g', 'numeric'},
#  'histidine': {'g', 'numeric'},
#  'hydroxyproline': {'g', 'numeric'},
#  'isoleucine': {'g', 'numeric'},
#  'leucine': {'g', 'numeric'},
#  'lysine': {'g', 'numeric'},
#  'methionine': {'g', 'numeric'},
#  'phenylalanine': {'g', 'numeric'},
#  'proline': {'g', 'numeric'},
#  'serine': {'g', 'numeric'},
#  'threonine': {'g', 'numeric'},
#  'tryptophan': {'g', 'numeric'},
#  'tyrosine': {'g', 'numeric'},
#  'valine': {'g', 'numeric'},
#  'carbohydrate': {'g'},
#  'fiber': {'g', 'numeric'},
#  'sugars': {'g', 'numeric'},
#  'fructose': {'g', 'numeric'},
#  'galactose': {'g', 'numeric'},
#  'glucose': {'g', 'numeric'},
#  'lactose': {'g', 'numeric'},
#  'maltose': {'g', 'numeric'},
#  'sucrose': {'g', 'numeric'},
#  'fat': {'g'},
#  'saturated_fatty_acids': {'g', 'numeric'},
#  'monounsaturated_fatty_acids': {'g', 'numeric'},
#  'polyunsaturated_fatty_acids': {'g', 'numeric'},
#  'fatty_acids_total_trans': {'mg', 'numeric'},
#  'alcohol': {'g', 'numeric'},
#  'ash': {'g', 'numeric'},
#  'caffeine': {'mg', 'numeric'},
#  'theobromine': {'mg', 'numeric'},
#  'water': {'g', 'numeric'}}

# %% [markdown]
# - to make units more clear, we can add an argument to rename the columns with their unit appended.
# - it will avoid `name` column altogether because it contains no unit info
# - it will specify units for dictionary items with multiple entries by avoiding the strings `numeric` and `nan`

# %%
# define a function which accepts input of a string containing a number (for the amount) plus a unit (g, mg, or mcg)
def check_unit(value):
    # first, convert each value to a string so the function can be applied
    # if a value is present (non-null), assign the string version of each value to `str_value`. if a null is encountered, an empty string is added
    str_value = str(value) if value is not None else ''
    
    # then, extract non-numeric information from each item in `str_value` and assign the result to `non_numeric`
    # the filter() tests each string using the lambda, which iterates thru the string and captures only non-digits and decimals ('.')
    # the outer method, ''.join(), concatenates any non-numeric characters found into one string
    # .strip() removes extra white spaces
    non_numeric = ''.join(filter(lambda x: not x.isdigit() and x != '.', str_value)).strip()
    return non_numeric if non_numeric else 'numeric'  # if `non_numeric` contains information it is returned; if it is empty, `numeric` is returned

# define an empty dictionary with which to store the differet resulting units, with column names as keys
column_units = {}
# defines an empty dictionary with which to store the new column names as values, with old column names as their keys
renamed_columns = {}

# this nested `for` loop applies `check_unit` function to all items in a df
for column in nutrition.select_dtypes(include=['object', 'float', 'int']).columns:   # iterates through columns in given dataframe
    if column == 'name':   # with the exception of `name`, which contains item descriptions
        continue            # tells the for loop to skip this column

    units_in_column = set()    # initializes an empty set called `units_in_columms` (a set is used because it will automatically show duplicates only once)
    
    # this inner loop will use the `check_unit` function on the values in columns
    for value in nutrition[column]:        # then, the nested loop iterates thru the values in each column
        unit = check_unit(value)    # the `check_unit` function is called for each value
        units_in_column.add(unit)   # the result returned from `check_unit` is then stored in the set, `units_in_column`
    column_units[column] = units_in_column  # once this inner loop finishes, the units found are stored in the `column_units` dictionary with column names as keys

    # use a list comprehension and 
    # create `units` list which is like `units_in_column` but leaves out 'numeric' and 'nan' items
    units = [u for u in units_in_column if u not in ['numeric', 'nan']]

    # for each item in `unit` list which is filled (not empty), rename the column with the present item
    if units:
        unit_to_add = units[0]  # grab the first (and only) unit
        new_column_name = f"{column}_{unit_to_add}"  # use constructor to append the unit's value to the column name in the format "_unit"
        renamed_columns[column] = new_column_name  # add the new column name as a value to each old column name key in the `renamed_columns` dictionary

nutrition.rename(columns=renamed_columns, inplace=True)  # carry out the renaming of the columns, using the `renamed_columns` dictionary as a mapping

nutrition.columns  # print the new column names
# Out:
# Index(['Unnamed: 0', 'name', 'serving_size_g', 'calories', 'total_fat_g',
#        'saturated_fat_g', 'cholesterol_mg', 'sodium_mg', 'choline_mg',
#        'folate_mcg', 'folic_acid_mcg', 'niacin_mg', 'pantothenic_acid_mg',
#        'riboflavin_mg', 'thiamin_mg', 'vitamin_a_mcg', 'vitamin_a_rae_mcg',
#        'carotene_alpha_mcg', 'carotene_beta_mcg', 'cryptoxanthin_beta_mcg',
#        'lutein_zeaxanthin_mcg', 'lucopene', 'vitamin_b12_mcg', 'vitamin_b6_mg',
#        'vitamin_c_mg', 'vitamin_d_IU', 'vitamin_e_mg', 'tocopherol_alpha_mg',
#        'vitamin_k_mcg', 'calcium_mg', 'copper_mg', 'irom_mg', 'magnesium_mg',
#        'manganese_mg', 'phosphorous_mg', 'potassium_mg', 'selenium_mcg',
#        'zink_mg', 'protein_g', 'alanine_g', 'arginine_g', 'aspartic_acid_g',
#        'cystine_g', 'glutamic_acid_g', 'glycine_g', 'histidine_g',
#        'hydroxyproline_g', 'isoleucine_g', 'leucine_g', 'lysine_g',
#        'methionine_g', 'phenylalanine_g', 'proline_g', 'serine_g',
#        'threonine_g', 'tryptophan_g', 'tyrosine_g', 'valine_g',
#        'carbohydrate_g', 'fiber_g', 'sugars_g', 'fructose_g', 'galactose_g',
#        'glucose_g', 'lactose_g', 'maltose_g', 'sucrose_g', 'fat_g',
#        'saturated_fatty_acids_g', 'monounsaturated_fatty_acids_g',
#        'polyunsaturated_fatty_acids_g', 'fatty_acids_total_trans_mg',
#        'alcohol_g', 'ash_g', 'caffeine_mg', 'theobromine_mg', 'water_g'],
#       dtype='object')

# %% [markdown]
# - then, we can remove the units from the individual values, converting them to floats so the data can be analyzed.

# %%
# iterate through columns in `nutrition`
for column in nutrition.columns:
    # detects columns with an understcore ("_"), which indicate possible presence of a newly appended unit
    if '_' in column:
        # to mitigate the multiple underscores in certain columns, this splits up these columns and stores each as a list of strings between underscores
        unit = column.split('_')[-1]  # the [-1] will select the last item in the list, as that is the appended unit

        # below, the column values are stripped of their units and converted to floats
        # values are converted to strings first using .astype(str)
        # the particular `unit` is found and replaced with a white space using str.replace(unit, '')
        # then the white space is stripped using str.strip()
        # finally the to_numeric() function converts strings to floats. errors='coerce' will ensure null values are set to 'NaN'
        nutrition[column] = pd.to_numeric(nutrition[column].astype(str).str.replace(unit, '').str.strip(), errors='coerce')

nutrition.head()  # check the results
# Out:
#    Unnamed: 0             name  serving_size_g  calories  total_fat_g  \
# 0           0       Cornstarch             100       381          0.1
# 1           1     Nuts, pecans             100       691         72.0
# 2           2    Eggplant, raw             100        25          0.2
# 3           3   Teff, uncooked             100       367          2.4
# 4           4  Sherbet, orange             100       144          2.0
#
#    saturated_fat_g  cholesterol_mg  sodium_mg  choline_mg  folate_mcg  ...  \
# 0              NaN               0        9.0         0.4         0.0  ...
# 1              6.2               0        0.0        40.5        22.0  ...
# 2              NaN               0        2.0         6.9        22.0  ...
# 3              0.4               0       12.0        13.1         0.0  ...
# 4              1.2               1       46.0         7.7         4.0  ...
#
#    fat_g  saturated_fatty_acids_g  monounsaturated_fatty_acids_g  \
# 0   0.05                    0.009                          0.016
# 1  71.97                    6.180                         40.801
# 2   0.18                    0.034                          0.016
# 3   2.38                    0.449                          0.589
# 4   2.00                    1.160                          0.530
#
#    polyunsaturated_fatty_acids_g  fatty_acids_total_trans_mg  alcohol_g  \
# 0                          0.025                         0.0        0.0
# 1                         21.614                         0.0        0.0
# 2                          0.076                         0.0        0.0
# 3                          1.071                         0.0        0.0
# 4                          0.080                         1.0        0.0
#
#    ash_g  caffeine_mg  theobromine_mg  water_g
# 0   0.09          0.0             0.0     8.32
# 1   1.49          0.0             0.0     3.52
# 2   0.66          0.0             0.0    92.30
# 3   2.37          0.0             0.0     8.82
# 4   0.40          0.0             0.0    66.10
#
# [5 rows x 77 columns]

# %% [markdown]
# Rechecking our msising values again. we can see that several values in the `vitamin_a_IU` column are now NaN because these ones contained `mcg` rather than `IU`.

# %%
# check for missing values
missing_values = nutrition.isnull().sum()

# calculate missing value counts for those columns where missing values are greater than zero
missing_values_df = pd.DataFrame(missing_values[missing_values > 0], columns=['Count Missing'])

# calculate the percentage of missing values for each column
missing_pct = ((missing_values / nutrition.shape[0] * 100).round(3))
# add missing count and percent to table
missing_values_df["% Missing"] = missing_pct

# check if there are no missing values, and print a message if that's the case
if missing_values_df.empty:
    print("There are no missing values.")
else:
    # display the table if there are missing values
    display(missing_values_df)
# Out:
#                  Count Missing  % Missing
# saturated_fat_g           1590     18.091
# vitamin_a_mcg             8078     91.910

# %% [markdown]
# examining the 7 missing values for `vitamin_a_IU`, they occur at indexes 1091, 1391, 1628, 2150, 2460, 3598, and 7422
#
# after clearing outputs and examining these indexes' values prior to their turning into NaNs, we see these are the original values:
# 1091 = 0.00 mcg, 1391 = 0.00 mcg, 1628 = 0.00 mcg, 2150 = 0.00 mcg, 2460 = 0.00 mcg, 3598 = 89.00 mcg, 7422 = 17.00 mcg
#
# below, we impute the indexes with original values of 0 mcg and convert the other two using the conversion of 1 IU = 0.3 mcg.
#
# now that we've turned everything into numerical values, we'll also fill in as many of `saturated_fat_g` with the zeroes in `total_fat_g`.

# %%
nutrition.query("vitamin_a_IU != vitamin_a_IU")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/scope.py:198, in Scope.resolve(self, key, is_local)
#     197 if self.has_resolvers:
# --> 198     return self.resolvers[key]
#     200 # if we're here that means that we have no locals and we also have
#     201 # no resolvers
#
# File ~/anaconda3/lib/python3.11/collections/__init__.py:1004, in ChainMap.__getitem__(self, key)
#    1003         pass
# -> 1004 return self.__missing__(key)
#
# File ~/anaconda3/lib/python3.11/collections/__init__.py:996, in ChainMap.__missing__(self, key)
#     995 def __missing__(self, key):
# --> 996     raise KeyError(key)
#
# KeyError: 'vitamin_a_IU'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/scope.py:209, in Scope.resolve(self, key, is_local)
#     205 try:
#     206     # last ditch effort we look in temporaries
#     207     # these are created when parsing indexing expressions
#     208     # e.g., df[df > 0]
# --> 209     return self.temps[key]
#     210 except KeyError as err:
#
# KeyError: 'vitamin_a_IU'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# /Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb Cell 30 line 1
# ----> <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> nutrition.query("vitamin_a_IU != vitamin_a_IU")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4474, in DataFrame.query(self, expr, inplace, **kwargs)
#    4472 kwargs["level"] = kwargs.pop("level", 0) + 2
#    4473 kwargs["target"] = None
# -> 4474 res = self.eval(expr, **kwargs)
#    4476 try:
#    4477     result = self.loc[res]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:4612, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4609     kwargs["target"] = self
#    4610 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4612 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/eval.py:353, in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     344 # get our (possibly passed-in) scope
#     345 env = ensure_scope(
#     346     level + 1,
#     347     global_dict=global_dict,
#    (...)
#     350     target=target,
#     351 )
# --> 353 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     355 # construct the engine and evaluate the parsed expression
#     356 eng = ENGINES[engine]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:813, in Expr.__init__(self, expr, engine, parser, env, level)
#     811 self.parser = parser
#     812 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 813 self.terms = self.parse()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:832, in Expr.parse(self)
#     828 def parse(self):
#     829     """
#     830     Parse an expression.
#     831     """
# --> 832     return self._visitor.visit(self.expr)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:421, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     419     raise SyntaxError("only a single expression is allowed")
#     420 expr = node.body[0]
# --> 421 return self.visit(expr, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:424, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     423 def visit_Expr(self, node, **kwargs):
# --> 424     return self.visit(node.value, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:723, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     721     op = self.translate_In(ops[0])
#     722     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 723     return self.visit(binop)
#     725 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     726 left = node.left
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:536, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     535 def visit_BinOp(self, node, **kwargs):
# --> 536     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     537     left, right = self._maybe_downcast_constants(left, right)
#     538     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:456, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     454 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     455     if left is None:
# --> 456         left = self.visit(node.left, side="left")
#     457     if right is None:
#     458         right = self.visit(node.right, side="right")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = "visit_" + type(node).__name__
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:549, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     548 def visit_Name(self, node, **kwargs):
# --> 549     return self.term_type(node.id, self.env, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/ops.py:85, in Term.__init__(self, name, env, side, encoding)
#      83 tname = str(name)
#      84 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 85 self._value = self._resolve_name()
#      86 self.encoding = encoding
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/ops.py:109, in Term._resolve_name(self)
#     104 if local_name in self.env.scope and isinstance(
#     105     self.env.scope[local_name], type
#     106 ):
#     107     is_local = False
# --> 109 res = self.env.resolve(local_name, is_local=is_local)
#     110 self.update(res)
#     112 if hasattr(res, "ndim") and res.ndim > 2:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/computation/scope.py:211, in Scope.resolve(self, key, is_local)
#     209     return self.temps[key]
#     210 except KeyError as err:
# --> 211     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'vitamin_a_IU' is not defined

# %%
# 1 IU vitamin A  = 0.3mcg of retinol (the form predominant in animal meat)
# 89.00 mcg = (1 IU / 0.3 mcg) 
print("impute the following for `vitamin_a_IU` for index 3598: ", 89.00 / 0.3)
print("impute the following for `vitamin_a_IU` for index 7422: ", 17.00 / 0.3)

# %%
# replacing missing values in vitamin a column
nutrition.loc[1091, 'vitamin_a_IU'] = '0.00'
nutrition.loc[1391, 'vitamin_a_IU'] = '0.00'
nutrition.loc[1628, 'vitamin_a_IU'] = '0.00'
nutrition.loc[2150, 'vitamin_a_IU'] = '0.00'
nutrition.loc[2460, 'vitamin_a_IU'] = '0.00'
nutrition.loc[3598, 'vitamin_a_IU'] = '296.666667'
nutrition.loc[7422, 'vitamin_a_IU'] = '56.666667'

# %%
# identify rows where `total_fat` is zero
zero_fat_rows = nutrition['total_fat_g'] == 0.0

# replace any NaN in `saturated_fat` column corresponding to the above rows
nutrition.loc[zero_fat_rows, 'saturated_fat_g'] = nutrition.loc[zero_fat_rows, 'saturated_fat_g'].fillna(0.0)

# %%
# check for missing values
missing_values = nutrition.isnull().sum()
# calculate missing value counts for those columns where missing values are greater than zero
missing_values_df = pd.DataFrame(missing_values[missing_values > 0], columns=['Count Missing'])
# calculate the percentage of missing values for each column
missing_pct = ((missing_values / nutrition.shape[0] * 100).round(3))
# add missing count and percent to table
missing_values_df["% Missing"] = missing_pct
# check if there are no missing values, and print a message if that's the case
if missing_values_df.empty:
    print("There are no missing values.")
else:
    # display the table if there are missing values
    display(missing_values_df)
# Out:
#                  Count Missing  % Missing
# saturated_fat_g           1139     12.959
# vitamin_a_mcg             8078     91.910

# %% [markdown]
# ## Creating a score system for foods using the Nutrient Rich Foods Index
# *"This NRF algorithm was represented by the sum of the percentage of the daily values of 9 nutrients to encourage (protein, fiber, vitamin A, vitamin C, vitamin E, calcium, iron, magnesium, and potassium) minus the sum of the percentage of the maximum recommended values for 3 nutrients to limit (saturated fat, added sugar, and sodium)."*
# Drewnowski A. The Nutrient Rich Foods Index helps to identify healthy, affordable foods. Am J Clin Nutr. 2010 Apr;91(4):1095S-1101S. doi: 10.3945/ajcn.2010.28450D. Epub 2010 Feb 24. PMID: 20181811.
# https://pubmed.ncbi.nlm.nih.gov/20181811/#:~:text=Background%3A%20The%20Nutrient%20Rich%20Foods,are%20both%20nutritious%20and%20affordable.
#
# (note: recc. daily values vary based on age, sex, lifestyle, pregnancy etc.)
#
# **daily values of 9 nutrients to encourage:**
# 1. protein: RDA (recc. daily allowance) for a 154 lb adult = ~56 g/day
# 2. fiber: AI (adequate intake) is 25g/day for women, 38g/day for men
# 3. vitamin A: RDA is 900mcg RAE (Retinol Activity Equivalents) per day for men, and 700 mcg RAE per day for women
# 4. vitamin C: RDA for Vitamin C is 90 mg/day for men and 75 mg/day for women. For smokers, an additional 35 mg per day is recommended
# 5. vitamin E: RDA is 15 mg (or 22.4 IU) of alpha-tocopherol per day
# 6. calcium: RDA is 1,000 mg/day for adults up to age 50 for men, and up to age 70 for women. 1,200 mg/day for women over 51 and men over 71
# 7. iron: RDA is 8 mg/day for men and 18 mg/day for women (ages 19-50), and 8 mg/day for women over 51
# 8. magnesium: RDA is 400-420 mg/day for men and 310-320 mg/day for women
# 9. potassium: AI is 2,600 mg/day for women and 3,400 mg/day for men
#
# **daily values of the maximum recommended values for 3 nutrients to limit:**
# 1. saturated fat: the Dietary Guidelines for Americans recommend limiting saturated fat to less than 10% of total daily calories. For someone consuming 2,000 calories a day, this would be less than 20 grams of saturated fat per day
# 2. added sugar: the Dietary Guidelines for Americans advise limiting added sugars to less than 10% of your daily caloric intake. For a 2,000-calorie diet, this equates to less than 50 grams of added sugars per day. The American Heart Association goes further, recommending no more than 6 teaspoons (25 grams) of added sugar per day for women and 9 teaspoons (38 grams) for men
# 3. sodium: the Dietary Guidelines for Americans suggest consuming less than 2,300 milligrams (mg) of sodium per day as part of a healthy eating pattern. The American Heart Association recommends an ideal limit of no more than 1,500 mg per day for most adults, especially for those with high blood pressure
#
#
# **calculation of nutrient scores**
# each nutrient amount is divided by its daily recommended value and then by the listed calorie content. this results in the nutrient density. the score for each nutrient amount per 100g is the proportion of it to its daily recommendation (or limit, for negative nutrients).
#
# 1. **(+) protein:**
# protein nutrient score = (*protein_g* / 56g) / *`calories`*
#
# 2. **(+) fiber:**
# fiber nutrient score (average) = (*`fiber_g`*/ 31.5g) / *`calories`*
#
# 3. **(+) vitamin A:**
# vitamin A nutrient score (average) = ((*`vitamin_a_IU`* /0.3)/ 800mcg) / *`calories`*
#
# 4. **(+) vitamin C:**
# vitamin C nutrient score (average, not including smokers) = (*`vitamin_c_mg`* / 82.5mg) / *`calories`*
#
# 5. **(+) vitamin E:**
# vitamin E nutrient score = (*`vitamin_e_mg`* / 15mg) / *calories*
#
# 6. **(+) calcium:**
# calcium nutrient score (average) = (*`calcium_mg`* / 1100mg) / *calories*
#
# 7. **(+) iron:**
# iron nutrient score (average) = (*iron_mg* / 13mg) / *calories*
#
# 8. **(+) magnesium:**
# magnesium nutrient score (average) = (*`magnesium_mg`* / 362.5mg) / *calories*     <- averaged between the given range
#
# 9. **(+) potassium:**
# potassium nutrient score (average) = (*`potassium_mg`* / 3000mg) / *calories*
#
# 1. **(-) saturated fat:**
# saturated fat nutrient score = (*`saturated_fat_g`* / 20g) / *calories*
#
# 2. **(-) added sugar:**
# added sugar nutrient score = (*`sugars_g`* / 20g) / *calories*
# ***note: since no data on specifically "added" sugars, we will use the `sugars` column as a rough approximation.
#
# 3. **(-) sodium:**
# sodium nutrient score (recommended) = (*`sodium_mg`* / 2300mg) / *calories*
# sodium nutrient score (ideal) = (*`sodium_mg`* / 1500mg) / *calories*
#
# b. take the sum of all the positive nutrient scores and the negative scores. Then subtract the negative scores from the positive, resulting in the overall NRF score for each item.
# NRF=∑(positive nutrient scores)−∑(negative nutrient scores)
#
# c. analyze: foods with higher NRF scores are more nutrient-rich and healthy in general.
#
# ** Notes:
# - we will not apply the function to food items which are zero-calorie (there are many drinks/drink mixes like this)
# - also we will avoid rows for which saturated fat is NaN because it is so integral to the calculation. this could be altered once those values are filled or deemed to be zero

# %%
# define functions to calculate NRF score for each food item 
# NRF algorithm for average adult 
def NRF_score_adult(row):
    calories = row['calories']  # define calories for the food item as one variable
    if (calories > 0) and (row['saturated_fat_g'] == row['saturated_fat_g']):  # apply the function only to rows where we know saturated fat and are >0 calories
        
        # scores for positive nutrients
        protein_score = (row['protein_g']/56)/calories
        fiber_score = (row['fiber_g']/31.5)/calories  
        #vitamin_a_score = ((row['vitamin_a_IU']/0.3)/900)/calories  
        vitamin_a_score = (row['vitamin_a_rae_mcg']/900)/calories 
        vitamin_c_score = (row['vitamin_c_mg']/82.5)/calories
        vitamin_e_score = (row['vitamin_e_mg']/15)/calories
        calcium_score = (row['calcium_mg']/1100)/calories   
        iron_score = (row['irom_mg']/13)/calories            
        magnesium_score = (row['magnesium_mg']/362.5)/calories
        potassium_score = (row['potassium_mg']/3000)/calories

        # scores for negative nutrients
        sat_fat_score = (row['saturated_fat_g']/20)
        sugar_score = (row['sugars_g']/20)
        sodium_score = (row['sodium_mg']/2300)
    
        # calculate totals for positive and negative
        positive_nutrients = protein_score + fiber_score + vitamin_a_score + vitamin_c_score + vitamin_e_score + calcium_score + iron_score + magnesium_score + potassium_score
        negative_nutrients = sat_fat_score + sugar_score + sodium_score

        # the overall NRF score is returned
        return positive_nutrients - negative_nutrients

# ensure all involved columns are numerical
columns_to_convert = ['protein_g', 'fiber_g', 'vitamin_a_rae_mcg', 'vitamin_c_mg', 'vitamin_e_mg', 
                      'calcium_mg', 'irom_mg', 'magnesium_mg', 'potassium_mg', 'saturated_fat_g', 'sugars_g', 
                      'sodium_mg', 'calories']
for col in columns_to_convert:
    nutrition[col] = pd.to_numeric(nutrition[col], errors='coerce')

# apply the function using multiple columns as inputs (axis=1), storing results in new columns
nutrition['NRF_score_adult'] = nutrition.apply(NRF_score_adult, axis=1)

# %%
# Scaling scores using z-score normalization (AKA standardization)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()  # instantiate the standardscaler
# apply the normalization and store result new columns
nutrition['NRF_score_adult_normalized'] = scaler.fit_transform(nutrition['NRF_score_adult'].values.reshape(-1, 1))

# %%
# Scaling scores using min-max method 
from sklearn.preprocessing import MinMaxScaler
# instantiate MinMax scaler with range of 0-10 for client interpretability
scaler = MinMaxScaler(feature_range=(0, 10))
# apply the scaling and store results in new columns
nutrition['NRF_score_adult_scaled'] = scaler.fit_transform(nutrition['NRF_score_adult'].values.reshape(-1, 1))

# %%
# convert `name` to lowercase so searches aren't case-sensitive
nutrition['name'] = nutrition['name'].str.lower()

# %%
import re
# 
fast_food_pattern = re.compile(r"mcdonalds|mcdonald's|burger king|kfc|kentucky fried chicken|subway|taco bell|wendys|wendy's|dominos|domino's pizza|pizza hut|starbucks|dunkin|dunkin' donuts|dunkin' doughnuts|chick-fil-a|chick fil a|chickfila|five guys|chipotle|panda express|little caesars|sonic|arbys|arby's|jack in the box|whataburger|in-n-out|in n out|innout")
mcdonalds_pattern = re.compile(r"mcdonalds|mcdonald's")
burger_king_pattern = re.compile(r'burger king')
kfc_pattern = re.compile(r'kfc|kentucky fried chicken')
subway_pattern = re.compile(r'subway')
taco_bell_pattern = re.compile(r'taco bell')
wendys_pattern = re.compile(r"wendys|wendy's")
dominos_pattern = re.compile(r"dominos|domino's pizza")
pizza_hut_pattern = re.compile(r'pizza hut')
starbucks_pattern = re.compile(r'starbucks')
dunkin_pattern = re.compile(r"dunkin|dunkin' donuts|dunkin' doughnuts")
chick_fil_a_pattern = re.compile(r'chick-fil-a|chick fil a|chickfila')
five_guys_pattern = re.compile(r'five guys')
chipotle_pattern = re.compile(r'chipotle')
panda_express_pattern = re.compile(r'panda express')
little_caesars_pattern = re.compile(r'little caesars')
sonic_pattern = re.compile(r'sonic')
arbys_pattern = re.compile(r"arbys|arby's")
jack_in_the_box_pattern = re.compile(r'jack in the box')
whataburger_pattern = re.compile(r'whataburger')
in_n_out_pattern = re.compile(r'in-n-out|in n out|innout')

# 
def contains_fast_food(item):
    if fast_food_pattern.search(item):
        return True
    else:
        return False

# apply the functions to `name` and new columns to store results
nutrition['fast food?'] = nutrition['name'].apply(contains_fast_food)

# %%
def fast_food_chains(item):
    fast_food_chains = {
        'Mcdonalds': mcdonalds_pattern,
        'Burger King': burger_king_pattern,
        'KFC': kfc_pattern,
        'Subway': subway_pattern,
        'Taco Bell': taco_bell_pattern,
        "Wendys": wendys_pattern,
        'Dominos': dominos_pattern,
        'Pizza Hut': pizza_hut_pattern,
        'Starbucks': starbucks_pattern,
        "Dunkin Donuts": dunkin_pattern,
        'Chick fil A': chick_fil_a_pattern,
        'Five Guys': five_guys_pattern,
        'Chipotle': chipotle_pattern,
        'Panda Express': panda_express_pattern,
        'Little Caesars': little_caesars_pattern,
        'Sonic': sonic_pattern,
        'Arbys': arbys_pattern,
        'Jack In the Box': jack_in_the_box_pattern,
        'Whataburger': whataburger_pattern,
        'In-n-Out': in_n_out_pattern
    }

    chains = []

    for chain, pattern in fast_food_chains.items():
        if pattern.search(item):
            chains.append(chain)

    return ', '.join(chains) if chains else 'None'

nutrition['Fast Food Chain'] = nutrition['name'].apply(fast_food_chains)
pd.reset_option('all')
nutrition.query("`fast food?` == True")
# Out:
# /var/folders/k8/29hfdmd56bs96xy1njxlppjc0000gn/T/ipykernel_14940/3772103021.py:34: FutureWarning: column_space is deprecated and will be removed in a future version. Use df.to_string(col_space=...) instead.
#   pd.reset_option('all')
# /var/folders/k8/29hfdmd56bs96xy1njxlppjc0000gn/T/ipykernel_14940/3772103021.py:34: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#   pd.reset_option('all')
# /var/folders/k8/29hfdmd56bs96xy1njxlppjc0000gn/T/ipykernel_14940/3772103021.py:34: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   pd.reset_option('all')
#       Unnamed: 0                                               name  \
# 31            31                             mcdonald's, side salad
# 34            34                             mcdonald's, hash brown
# 62            62                              wendy's, french fries
# 83            83                              mcdonald's, hamburger
# 100          100                              taco bell, taco salad
# ...          ...                                                ...
# 7380        7380  little caesars 14" original round meat and veg...
# 7421        7421  kfc, meat and skin with breading, drumstick, e...
# 7422        7422  kfc, meat and skin with breading, breast, orig...
# 7525        7525  subway, tomato and sweet onion sauce, sweet on...
# 8159        8159  kfc, skin and breading removed, meat only, dru...
#
#       serving_size_g  calories  total_fat_g  saturated_fat_g  cholesterol_mg  \
# 31               100        20          0.2              NaN               0
# 34               100       271         16.0              2.3               0
# 62               100       301         14.0              2.8               0
# 83               100       264         10.0              3.5              27
# 100              100       170          9.2              3.0              19
# ...              ...       ...          ...              ...             ...
# 7380             100       243         11.0              4.6              31
# 7421             100       274         18.0              3.9             109
# 7422             100       231         13.0              3.0              81
# 7525             100       155          2.4              0.5              22
# 8159             100       175          7.7              1.8             137
#
#       sodium_mg  choline_mg  folate_mcg  ...  alcohol_g  ash_g  caffeine_mg  \
# 31         12.0         0.0        57.0  ...        0.0   0.54          0.0
# 34        580.0         0.0        12.0  ...        0.0   2.25          0.0
# 62        219.0        33.0         0.0  ...        0.0   1.83          0.0
# 83        494.0         0.0        64.0  ...        0.0   2.18          0.0
# 100       363.0         0.0        43.0  ...        0.0   1.71          0.0
# ...         ...         ...         ...  ...        ...    ...          ...
# 7380      578.0         0.0         0.0  ...        0.0   2.32          0.0
# 7421      632.0         0.0         0.0  ...        0.0   2.38          0.0
# 7422      606.0         0.0         0.0  ...        0.0   2.51          0.0
# 7525      305.0         0.0        58.0  ...        0.0   1.78          0.0
# 8159      524.0         0.0         0.0  ...        0.0   2.16          0.0
#
#       theobromine_mg  water_g  NRF_score_adult  NRF_score_adult_normalized  \
# 31               0.0    93.93              NaN                         NaN
# 34               0.0    50.42        -0.392060                    0.323136
# 62               0.0    40.62        -0.252698                    0.484090
# 83               0.0    44.53        -0.688489                   -0.019219
# 100              0.0    67.32        -0.304136                    0.424682
# ...              ...      ...              ...                         ...
# 7380             0.0    51.10        -0.664840                    0.008094
# 7421             0.0    51.44        -0.467601                    0.235892
# 7422             0.0    56.16        -0.410687                    0.301623
# 7525             0.0    62.40        -0.456226                    0.249029
# 8159             0.0    63.77        -0.313720                    0.413614
#
#       NRF_score_adult_scaled  fast food?  Fast Food Chain
# 31                       NaN        True        Mcdonalds
# 34                  9.209846        True        Mcdonalds
# 62                  9.317173        True           Wendys
# 83                  8.981556        True        Mcdonalds
# 100                 9.277559        True        Taco Bell
# ...                      ...         ...              ...
# 7380                8.999769        True   Little Caesars
# 7421                9.151669        True              KFC
# 7422                9.195500        True              KFC
# 7525                9.160430        True           Subway
# 8159                9.270178        True              KFC
#
# [171 rows x 82 columns]

# %%
# Plot: 
import matplotlib.pyplot as plt
import seaborn as sns
fast_food = nutrition.query("`fast food?` == True")
f, ax = plt.subplots(figsize=(7, 3))
f.subplots_adjust(wspace=0.1)
sns.countplot(y='Fast Food Chain', ax=ax, data=fast_food)
ax.set_title('Fast food chains')
ax.set_ylabel('NRF Score', rotation=0)  # customize the y-axis label
ax.get_yaxis().set_label_coords(-0.25,0.43)  # Adjust y-axis label position
plt.show()

# %%
# Plot: 
fast_food = nutrition.query("`fast food?` == True")
f, ax = plt.subplots(figsize=(7, 3))
f.subplots_adjust(wspace=0.1)
sns.boxplot(y='Fast Food Chain', x='NRF_score_adult_scaled', ax=ax, data=fast_food)
ax.set_title('Fast food chains')
ax.set_ylabel('NRF Score', rotation=0)  # customize the y-axis label
ax.get_yaxis().set_label_coords(-0.25,0.43)  # Adjust y-axis label position
plt.show()

# %%
# 
#cheese_pattern = re.compile(r"mcdonalds|mcdonald's|burger king|kfc|kentucky fried chicken|subway|taco bell|wendys|wendy's|dominos|domino's pizza|pizza hut|starbucks|dunkin|dunkin' donuts|dunkin' doughnuts|chick-fil-a|chick fil a|chickfila|five guys|chipotle|panda express|little caesars|sonic|arbys|arby's|jack in the box|whataburger|in-n-out|in n out|innout")
cheddar_cheese_pattern = re.compile(r'cheddar cheese|cheddar|cheese, cheddar')
mozzarella_cheese_pattern = re.compile(r'mozzarella cheese|mozzarella|cheese, mozzarella')
parmesan_cheese_pattern = re.compile(r'parmesan cheese|parmesan|cheese, parmesan')
gouda_cheese_pattern = re.compile(r'gouda cheese|gouda|cheese, gouda')
brie_cheese_pattern = re.compile(r'brie cheese|brie|cheese, brie')
camembert_cheese_pattern = re.compile(r'camembert cheese|camembert|cheese, camembert')
blue_cheese_pattern = re.compile(r'(blue cheese|gorgonzola|roquefort|stilton|cheese, blue|cheese, gorgonzola|cheese, roquefort|cheese, stilton)')
feta_cheese_pattern = re.compile(r'feta cheese|feta|cheese, feta')
ricotta_cheese_pattern = re.compile(r'ricotta cheese|ricotta|cheese, ricotta')
goat_cheese_pattern = re.compile(r'(goat cheese|chevre|cheese, goat)')
swiss_cheese_pattern = re.compile(r'swiss cheese|swiss|cheese, swiss')
gorgonzola_cheese_pattern = re.compile(r'gorgonzola cheese|gorgonzola|cheese, gorgonzola')
havarti_cheese_pattern = re.compile(r'havarti cheese|havarti|cheese, havarti')
monterey_jack_cheese_pattern = re.compile(r'monterey jack cheese|monterey jack|cheese, monterey jack')
pecorino_cheese_pattern = re.compile(r'pecorino cheese|pecorino|cheese, pecorino')
manchego_cheese_pattern = re.compile(r'manchego cheese|manchego|cheese, manchego')
asiago_cheese_pattern = re.compile(r'asiago cheese|asiago|cheese, asiago')
halloumi_cheese_pattern = re.compile(r'halloumi cheese|halloumi|cheese, halloumi')
provolone_cheese_pattern = re.compile(r'provolone cheese|provolone|cheese, provolone')
emmental_cheese_pattern = re.compile(r'emmental cheese|emmental|cheese, emmental')
edam_cheese_pattern = re.compile(r'edam cheese|edam|cheese, edam')
colby_jack_cheese_pattern = re.compile(r'colby jack cheese|colby jack|cheese, colby jack|colby cheese|colby|cheese, colby')
cream_cheese_pattern = re.compile(r'cream cheese')

# 
def contains_cheese(item):
    if cheddar_cheese_pattern.search(item) or mozzarella_cheese_pattern.search(item) or parmesan_cheese_pattern.search(item) or gouda_cheese_pattern.search(item) or brie_cheese_pattern.search(item) or camembert_cheese_pattern.search(item) or blue_cheese_pattern.search(item) or feta_cheese_pattern.search(item) or ricotta_cheese_pattern.search(item) or goat_cheese_pattern.search(item) or swiss_cheese_pattern.search(item) or gorgonzola_cheese_pattern.search(item) or havarti_cheese_pattern.search(item) or monterey_jack_cheese_pattern.search(item) or pecorino_cheese_pattern.search(item) or manchego_cheese_pattern.search(item) or asiago_cheese_pattern.search(item) or halloumi_cheese_pattern.search(item) or provolone_cheese_pattern.search(item) or emmental_cheese_pattern.search(item) or edam_cheese_pattern.search(item) or colby_jack_cheese_pattern.search(item) or cream_cheese_pattern.search(item):
        return True
    else:
        return False

# apply the functions to `name` and new columns to store results
nutrition['cheese?'] = nutrition['name'].apply(contains_cheese)

# %%
def cheese_variety(item):
    cheese_varieties = {
        'Cheddar Cheese': cheddar_cheese_pattern,
        'Mozzarella Cheese': mozzarella_cheese_pattern,
        'Parmesan Cheese': parmesan_cheese_pattern,
        'Gouda Cheese': gouda_cheese_pattern,
        'Brie Cheese': brie_cheese_pattern,
        'Camembert Cheese': camembert_cheese_pattern,
        'Blue Cheese': blue_cheese_pattern, 
        'Feta Cheese': feta_cheese_pattern,
        'Ricotta Cheese': ricotta_cheese_pattern,
        'Goat Cheese': goat_cheese_pattern,
        'Swiss Cheese': swiss_cheese_pattern,
        'Gorgonzola Cheese': gorgonzola_cheese_pattern,
        'Havarti Cheese': havarti_cheese_pattern,
        'Monterey Jack': monterey_jack_cheese_pattern,
        'Pecorino Cheese': pecorino_cheese_pattern,
        'Manchego Cheese': manchego_cheese_pattern,
        'Asiago Cheese': asiago_cheese_pattern,
        'Halloumi Cheese': halloumi_cheese_pattern,
        'Provolone Cheese': provolone_cheese_pattern,
        'Emmental Cheese': emmental_cheese_pattern,
        'Edam Cheese': edam_cheese_pattern,
        'Colby Jack': colby_jack_cheese_pattern,
        'Cream Cheese': cream_cheese_pattern
    }

    varieties = []

    for variety, pattern in cheese_varieties.items():
        if pattern.search(item):
            varieties.append(variety)

    return ', '.join(varieties) if varieties else 'None'

# Example usage in DataFrame
nutrition['variety'] = nutrition['name'].apply(cheese_variety)

# %%
# Plot: 

cheeses = nutrition.query("`cheese?` == True")
f, ax = plt.subplots(figsize=(7, 4))
f.subplots_adjust(wspace=0.1)
sns.countplot(y='variety', ax=ax, data=cheeses)
ax.set_title('cheeses')
ax.set_ylabel('', rotation=0)  # customize the y-axis label
ax.get_yaxis().set_label_coords(-0.25,0.43)  # Adjust y-axis label position
plt.show()

# %%
# Plot: 
cheeses = nutrition.query("`cheese?` == True")
f, ax = plt.subplots(figsize=(7, 5))
f.subplots_adjust(wspace=0.1)
sns.boxplot(y='variety', x='NRF_score_adult_scaled', ax=ax, data=cheeses)
ax.set_title('cheeses')
ax.set_ylabel('', rotation=0)  # customize the y-axis label
ax.get_yaxis().set_label_coords(-0.25,0.43)  # Adjust y-axis label position
plt.show()

# %%
plain_yogurt_pattern = re.compile(r'plain yogurt')
greek_yogurt_pattern = re.compile(r'greek yogurt')
icelandic_yogurt_pattern = re.compile(r'(icelandic yogurt|skyr)')
australian_yogurt_pattern = re.compile(r'australian yogurt')
soy_yogurt_pattern = re.compile(r'soy yogurt')
almond_yogurt_pattern = re.compile(r'almond yogurt')
coconut_yogurt_pattern = re.compile(r'coconut yogurt')
oat_yogurt_pattern = re.compile(r'oat yogurt')
flavored_yogurt_pattern = re.compile(r'(flavored yogurt|strawberry yogurt|blueberry yogurt|vanilla yogurt|peach yogurt)')
low_fat_yogurt_pattern = re.compile(r'low-fat yogurt')
non_fat_yogurt_pattern = re.compile(r'non-fat yogurt')
full_fat_yogurt_pattern = re.compile(r'full-fat yogurt')
lactose_free_yogurt_pattern = re.compile(r'lactose-free yogurt')
probiotic_yogurt_pattern = re.compile(r'probiotic yogurt')
bulgarian_yogurt_pattern = re.compile(r'bulgarian yogurt')
indian_yogurt_pattern = re.compile(r'(indian yogurt|dahi)')
turkish_yogurt_pattern = re.compile(r'turkish yogurt')


# 
def contains_yogurt(item):
    if cheddar_cheese_pattern.search(item) or mozzarella_cheese_pattern.search(item) or parmesan_cheese_pattern.search(item) or gouda_cheese_pattern.search(item) or brie_cheese_pattern.search(item) or camembert_cheese_pattern.search(item) or blue_cheese_pattern.search(item) or feta_cheese_pattern.search(item) or ricotta_cheese_pattern.search(item) or goat_cheese_pattern.search(item) or swiss_cheese_pattern.search(item) or gorgonzola_cheese_pattern.search(item) or havarti_cheese_pattern.search(item) or monterey_jack_cheese_pattern.search(item) or pecorino_cheese_pattern.search(item) or manchego_cheese_pattern.search(item) or asiago_cheese_pattern.search(item) or halloumi_cheese_pattern.search(item) or provolone_cheese_pattern.search(item) or emmental_cheese_pattern.search(item) or edam_cheese_pattern.search(item) or colby_jack_cheese_pattern.search(item) or cream_cheese_pattern.search(item):
        return True
    else:
        return False

# apply the functions to `name` and new columns to store results
nutrition['yogurt?'] = nutrition['name'].apply(contains_yogurt)

# %%
leafy_green_vegetables_pattern = re.compile(r'(spinach|kale|collard\sgreens|mustard\sgreens|swiss\schard|turnip\sgreens|seaweed|bok\schoy|broccoli|rabe|arugula|watercress)')
red_orange_vegetables_pattern = re.compile(r'(carrot|pumpkin|sweet\spotato|red\spepper|orange\spepper|butternut\ssquash|acorn\ssquash|tomato|beet|red\sonion)')
beans_peas_pattern = re.compile(r'(black\sbeans|kidney\sbeans|pinto\sbeans|navy\sbeans|chickpeas|lentils|split\speas|green\speas|black-eyed\speas|lima\sbeans)')
starchy_vegetables_pattern = re.compile(r'(potato|corn|green\speas|butternut\ssquash|acorn\ssquash|pumpkin|plantain|yam|taro|cassava)')
other_vegetables_pattern = re.compile(r'(cucumber|bell\spepper|zucchini|squash|eggplant|lettuce|celery|cabbage|brussels\ssprouts|cauliflower|artichoke|asparagus|radish)')

def contains_vegetables(item):
    if leafy_green_vegetables_pattern.search(item) or red_orange_vegetables_pattern.search(item) or beans_peas_pattern.search(item) or starchy_vegetables_pattern.search(item) or other_vegetables_pattern.search(item):
        return True
    else:
        return False

# apply the functions to `name` and new columns to store results
nutrition['veggies?'] = nutrition['name'].apply(contains_vegetables)

# %%
def veggie_variety(item):
    veggie_varieties = {
        'Leafy Green Vegetables': leafy_green_vegetables_pattern,
        'Red/Orange Vegetables': red_orange_vegetables_pattern,
        'Beans/Peas': beans_peas_pattern,
        'Starchy Vegetables': starchy_vegetables_pattern,
        'Other Vegetables': other_vegetables_pattern,
    }

    varieties = []

    for variety, pattern in varieties.items():
        if pattern.search(item):
            varieties.append(variety)

    return ', '.join(varieties) if varieties else 'None'

nutrition['veggie_variety'] = nutrition['name'].apply(veggie_variety)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb Cell 50 line 1
#      <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb#X66sZmlsZQ%3D%3D?line=13'>14</a>             varieties.append(variety)
#      <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb#X66sZmlsZQ%3D%3D?line=15'>16</a>     return ', '.join(varieties) if varieties else 'None'
# ---> <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb#X66sZmlsZQ%3D%3D?line=17'>18</a> nutrition['veggie_variety'] = nutrition['name'].apply(veggie_variety)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# /Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb Cell 50 line 1
#       <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb#X66sZmlsZQ%3D%3D?line=1'>2</a> veggie_varieties = {
#       <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb#X66sZmlsZQ%3D%3D?line=2'>3</a>     'Leafy Green Vegetables': leafy_green_vegetables_pattern,
#       <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb#X66sZmlsZQ%3D%3D?line=3'>4</a>     'Red/Orange Vegetables': red_orange_vegetables_pattern,
#    (...)
#       <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb#X66sZmlsZQ%3D%3D?line=6'>7</a>     'Other Vegetables': other_vegetables_pattern,
#       <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb#X66sZmlsZQ%3D%3D?line=7'>8</a> }
#      <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb#X66sZmlsZQ%3D%3D?line=9'>10</a> varieties = []
# ---> <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb#X66sZmlsZQ%3D%3D?line=11'>12</a> for variety, pattern in varieties.items():
#      <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb#X66sZmlsZQ%3D%3D?line=12'>13</a>     if pattern.search(item):
#      <a href='vscode-notebook-cell:/Users/mollyscally/DATA3500/Section_4_Data_Dives/Case4/DataDive4_DATA3500/nutrition_working.ipynb#X66sZmlsZQ%3D%3D?line=13'>14</a>         varieties.append(variety)
#
# AttributeError: 'list' object has no attribute 'items'

# %%
def veggie_variety(item):
    veggie_varieties_patterns = {
        'Leafy Green Vegetables': leafy_green_vegetables_pattern,
        'Red/Orange Vegetables': red_orange_vegetables_pattern,
        'Beans/Peas': beans_peas_pattern,
        'Starchy Vegetables': starchy_vegetables_pattern,
        'Other Vegetables': other_vegetables_pattern,
    }

    found_veggie_varieties = []

    for variety, pattern in veggie_varieties_patterns.items():
        if pattern.search(item):
            found_veggie_varieties.append(variety)

    return ', '.join(found_veggie_varieties) if found_veggie_varieties else 'None'

nutrition['veggie_variety'] = nutrition['name'].apply(veggie_variety)

# %%
# Plot: 

veggies = nutrition.query("`veggies?` == True")
f, ax = plt.subplots(figsize=(7, 4))
f.subplots_adjust(wspace=0.1)
sns.countplot(y='veggie_variety', ax=ax, data=veggies)
ax.set_title('veggies')
ax.set_ylabel('', rotation=0)  # customize the y-axis label
ax.get_yaxis().set_label_coords(-0.25,0.43)  # Adjust y-axis label position
plt.show()

# %%
# Plot: 
cheeses = nutrition.query("`veggies?` == True")
f, ax = plt.subplots(figsize=(7, 5))
f.subplots_adjust(wspace=0.1)
sns.boxplot(y='veggie_variety', x='NRF_score_adult_scaled', ax=ax, data=cheeses)
ax.set_title('veggies')
ax.set_ylabel('', rotation=0)  # customize the y-axis label
ax.get_yaxis().set_label_coords(-0.25,0.43)  # Adjust y-axis label position
plt.show()

# %%
whole_grain_pattern = re.compile(r'(whole\swheat\sbread|brown\srice|popcorn|oatmeal|quinoa|wild\srice|bulgur|buckwheat|barley|millets|sorghum|whole\srice|whole\swheat\spasta|whole\swheat\tortillas|rye\sbread|whole\swheat\sbagels|spelt|amaranth|teff|triticale|whole\swheat\senglish\smuffins|whole\swheat\spretzels)')
refined_grain_pattern = re.compile(r'(white\sbread|white\srice|pretzels|english\smuffins|corn\stortilla|grits|regular\spasta|bagels|crackers|noodles|pancakes|waffles|white\sflour\stortillas|croissants|pita\sbread|refined\scereal|refined\swheat\sflour|refined\soat\sproducts|refined\sbarley\sproducts|refined\scorn\sproducts)')

def contains_grains(item):
    if whole_grain_pattern.search(item) or refined_grain_pattern.search(item):
        return True
    else:
        return False

# apply the functions to `name` and new columns to store results
nutrition['grains?'] = nutrition['name'].apply(contains_grains)

# %%
def grains_variety(item):
    grains_varieties_patterns = {
        'Whole Grain': whole_grain_pattern,
        'Refined Grain': refined_grain_pattern
    }

    found_grains_varieties = []

    for variety, pattern in grains_varieties_patterns.items():
        if pattern.search(item):
            found_grains_varieties.append(variety)

    return ', '.join(found_grains_varieties) if found_grains_varieties else 'None'

nutrition['grains_variety'] = nutrition['name'].apply(grains_variety)

# %%
# Plot: 

grains = nutrition.query("`grains?` == True")
f, ax = plt.subplots(figsize=(7, 4))
f.subplots_adjust(wspace=0.1)
sns.countplot(y='grains_variety', ax=ax, data=grains)
ax.set_title('grains')
ax.set_ylabel('', rotation=0)  # customize the y-axis label
ax.get_yaxis().set_label_coords(-0.25,0.43)  # Adjust y-axis label position
plt.show()

# %%
# Plot: 
cheeses = nutrition.query("`grains?` == True")
f, ax = plt.subplots(figsize=(7, 5))
f.subplots_adjust(wspace=0.1)
sns.boxplot(y='grains_variety', x='NRF_score_adult_scaled', ax=ax, data=cheeses)
ax.set_title('grains')
ax.set_ylabel('', rotation=0)  # customize the y-axis label
ax.get_yaxis().set_label_coords(-0.25,0.43)  # Adjust y-axis label position
plt.show()

# %%
meats_pattern = re.compile(r'(?i)(Lean\sCuts|beef|goat|ham|lamb|pork|Lean\sGround\sMeats|beef|pork|Lean\sLuncheon/\sDeli\sMeats|beef|chicken|ham|pork|turkey|Game\sMeats|bear|bison|deer|elk|moose|opossum|rabbit|raccoon|squirrel|venison|Organ\sMeats|brain|chitterlings|giblets|gizzard|heart|kidney|liver|stomach|sweetbreads|tongue|tripe)')

poultry_pattern = re.compile(r'(chicken|Cornish\shen|dove|duck|goose|ostrich|pheasant|quail|turkey)')

nuts_seeds_soy_pattern = re.compile(r'(?i)(almonds|almond\sbutter|Brazil\snuts|cashew\sbutter|cashews|chestnuts|chia\sseeds|flax\sseeds|hazelnuts\s\(filberts\)|macadamia\snuts|mixed\snuts|peanut\sbutter|peanuts|pecans|pine\snuts|pistachios|pumpkin\sseeds|sesame\sbutter\sor\spaste\s\(tahini\)|sesame\sseeds|sunflower\sbutter|sunflower\sseeds|tempeh|texturized\svegetable\sprotein\s\(TVP\)|tofu\s\(made\sfrom\ssoybeans\)|veggie\sburgers\s\(made\sfrom\ssoybeans\)|walnuts)')

seafood_pattern = re.compile(r'(?i)(fish|shark|tuna|salmon|trout|mackerel|sardine|anchovy|cod|tilapia|halibut|catfish|snapper|swordfish|bass|grouper|perch|sole|flounder|crab|lobster|shrimp|prawn|clam|oyster|mussel|scallop|squid|octopus|crayfish|eel|Finfish|black\ssea\sbass|catfish|cod|flounder|freshwater\strout|haddock|hake|halibut|herring|light\stuna|mackerel|mullet|perch|pollock|salmon|sea\sbass|snapper|sole|sushi|tilapia|whiting|Shellfish|clams|crab|crayfish|lobster|mussels|octopus|oysters|scallops|shrimp|squid\s\(calamari\)|Canned\sFish|anchovies|freshwater\strout|herring|light\stuna|salmon|sardines)')

eggs_pattern = re.compile(r'(?i)(chicken\seggs|duck\seggs|egg\sproducts|quail\seggs|goose\seggs|turkey\seggs)')


def protein_sources(item):
    if meats_pattern.search(item) or poultry_pattern.search(item) or nuts_seeds_soy_pattern.search(item) or seafood_pattern.search(item) or eggs_pattern.search(item):
        return True
    else:
        return False

# apply the functions to `name` and new columns to store results
nutrition['protein source?'] = nutrition['name'].apply(protein_sources)

# %%
def protein_source_types(item):
    protein_type_patterns = {
        'Meats': meats_pattern,
        'Poultry': poultry_pattern,
        'Nuts/Seeds/Soy': nuts_seeds_soy_pattern,
        'Seafood': seafood_pattern,
        'Eggs': eggs_pattern
    }

    found_protein_types = []

    for variety, pattern in protein_type_patterns.items():
        if pattern.search(item):
            found_protein_types.append(variety)

    return ', '.join(found_protein_types) if found_protein_types else 'None'

nutrition['protein_type'] = nutrition['name'].apply(protein_source_types)

# %%
# Plot: 

protein_sources_filter = nutrition.query("`protein source?` == True")
f, ax = plt.subplots(figsize=(7, 4))
f.subplots_adjust(wspace=0.1)
sns.countplot(y='protein_type', ax=ax, data=protein_sources_filter)
ax.set_title('protein type')
ax.set_ylabel('', rotation=0)  # customize the y-axis label
ax.get_yaxis().set_label_coords(-0.25,0.43)  # Adjust y-axis label position
plt.show()

# %%
# Plot: 
protein_sources_filter = nutrition.query("`protein source?` == True")
f, ax = plt.subplots(figsize=(7, 5))
f.subplots_adjust(wspace=0.1)
sns.boxplot(y='protein_type', x='NRF_score_adult_scaled', ax=ax, data=protein_sources_filter)
ax.set_title('proteins')
ax.set_ylabel('', rotation=0)  # customize the y-axis label
ax.get_yaxis().set_label_coords(-0.25,0.43)  # Adjust y-axis label position
plt.show()

# %%
lean_meats_pattern = re.compile(r'(lean|skinless|boneless|tenderloin|sirloin)\s(meat|poultry|beef|pork|chicken|turkey)')
fatty_meat_pattern = re.compile(r'(fatty|high\s*fat)\s(meat|poultry|beef|pork|lamb|sausage|bacon|ribs)')
processed_meat_pattern = re.compile(r'(processed|deli|cured|smoked|canned)\s(meat|poultry)')
red_meat_pattern = re.compile(r'(red|beef|pork|lamb)\s(meat)')
white_meat_pattern = re.compile(r'(white)\s(meat|poultry|chicken|turkey)')
game_meat_pattern = re.compile(r'(game|wild)\s(meat)')
organ_meats_pattern = re.compile(r'(organ|offal)\s(meat|poultry|beef|pork|liver|kidney|heart)')
processed_poultry_pattern = re.compile(r'(processed)\s(poultry|chicken|turkey)')
nuts_seeds_soy_pattern = re.compile(r'(almonds|almond\sbutter|Brazil\snuts|cashew\sbutter|cashews|chestnuts|chia\sseeds|flax\sseeds|hazelnuts\s\(filberts\)|macadamia\snuts|mixed\snuts|peanut\sbutter|peanuts|pecans|pine\snuts|pistachios|pumpkin\sseeds|sesame\sbutter\sor\spaste\s\(tahini\)|sesame\sseeds|sunflower\sbutter|sunflower\sseeds|tempeh|texturized\svegetable\sprotein\s\(TVP\)|tofu\s\(made\sfrom\ssoybeans\)|veggie\sburgers\s\(made\sfrom\ssoybeans\)|walnuts)')
seafood_pattern = re.compile(r'(fish|shark|tuna|salmon|trout|mackerel|sardine|anchovy|cod|tilapia|halibut|catfish|snapper|swordfish|bass|grouper|perch|sole|flounder|crab|lobster|shrimp|prawn|clam|oyster|mussel|scallop|squid|octopus|crayfish|eel|Finfish|black\ssea\sbass|catfish|cod|flounder|freshwater\strout|haddock|hake|halibut|herring|light\stuna|mackerel|mullet|perch|pollock|salmon|sea\sbass|snapper|sole|sushi|tilapia|whiting|Shellfish|clams|crab|crayfish|lobster|mussels|octopus|oysters|scallops|shrimp|squid\s\(calamari\)|Canned\sFish|anchovies|freshwater\strout|herring|light\stuna|salmon|sardines)')
eggs_pattern = re.compile(r'(chicken\seggs|duck\seggs|egg\sproducts|quail\seggs|goose\seggs|turkey\seggs)')

def protein_sources_new(item):
    if lean_meats_pattern.search(item) or fatty_meat_pattern.search(item) or processed_meat_pattern.search(item) or red_meat_pattern.search(item) or white_meat_pattern.search(item) or game_meat_pattern.search(item) or organ_meats_pattern.search(item) or processed_poultry_pattern.search(item) or nuts_seeds_soy_pattern.search(item) or seafood_pattern.search(item) or eggs_pattern.search(item):
        return True
    else:
        return False

# apply the functions to `name` and new columns to store results
nutrition['protein source new?'] = nutrition['name'].apply(protein_sources_new)

# %%
# 2
lean_meat_pattern2 = re.compile(r'(?i)(Lean\sCuts)')
fatty_meat_pattern2 = re.compile(r'(?i)(beef|goat|ham|lamb|pork)')
processed_meat_pattern2 = re.compile(r'(?i)(Lean\sGround\sMeats|beef|pork|Lean\sLuncheon/\sDeli\sMeats|beef|chicken|ham|pork|turkey)')
red_meat_pattern2 = re.compile(r'(?i)(beef|goat|ham|lamb|pork)')
white_meat_pattern2 = re.compile(r'(?i)(chicken|Cornish\shen|dove|duck|goose|ostrich|pheasant|quail|turkey)')
game_meat_pattern2 = re.compile(r'(?i)(bear|bison|deer|elk|moose|opossum|rabbit|raccoon|squirrel|venison)')
organ_meats_pattern2 = re.compile(r'(?i)(brain|chitterlings|giblets|gizzard|heart|kidney|liver|stomach|sweetbreads|tongue|tripe)')
processed_poultry_pattern2 = re.compile(r'(?i)(Lean\sLuncheon/\sDeli\sMeats|chicken|ham|turkey)')
nuts_seeds_soy_pattern2 = re.compile(r'(almonds|almond\sbutter|Brazil\snuts|cashew\sbutter|cashews|chestnuts|chia\sseeds|flax\sseeds|hazelnuts\s\(filberts\)|macadamia\snuts|mixed\snuts|peanut\sbutter|peanuts|pecans|pine\snuts|pistachios|pumpkin\sseeds|sesame\sbutter\sor\spaste\s\(tahini\)|sesame\sseeds|sunflower\sbutter|sunflower\sseeds|tempeh|texturized\svegetable\sprotein\s\(TVP\)|tofu\s\(made\sfrom\ssoybeans\)|veggie\sburgers\s\(made\sfrom\ssoybeans\)|walnuts)')
seafood_pattern2 = re.compile(r'(fish|shark|tuna|salmon|trout|mackerel|sardine|anchovy|cod|tilapia|halibut|catfish|snapper|swordfish|bass|grouper|perch|sole|flounder|crab|lobster|shrimp|prawn|clam|oyster|mussel|scallop|squid|octopus|crayfish|eel|Finfish|black\ssea\sbass|catfish|cod|flounder|freshwater\strout|haddock|hake|halibut|herring|light\stuna|mackerel|mullet|perch|pollock|salmon|sea\sbass|snapper|sole|sushi|tilapia|whiting|Shellfish|clams|crab|crayfish|lobster|mussels|octopus|oysters|scallops|shrimp|squid\s\(calamari\)|Canned\sFish|anchovies|freshwater\strout|herring|light\stuna|salmon|sardines)')
eggs_pattern2 = re.compile(r'(chicken\seggs|duck\seggs|egg\sproducts|quail\seggs|goose\seggs|turkey\seggs)')

def protein_sources_new2(item):
    if lean_meat_pattern2.search(item) or fatty_meat_pattern2.search(item) or processed_meat_pattern2.search(item) or red_meat_pattern2.search(item) or white_meat_pattern2.search(item) or game_meat_pattern2.search(item) or organ_meats_pattern2.search(item) or processed_poultry_pattern2.search(item) or nuts_seeds_soy_pattern2.search(item) or seafood_pattern2.search(item) or eggs_pattern2.search(item):
        return True
    else:
        return False

# apply the functions to `name` and new columns to store results
nutrition['protein source new2?'] = nutrition['name'].apply(protein_sources_new2)

# %%
def protein_source_types_new(item):
    protein_type_patterns = {
        'Lean Meat': lean_meats_pattern,
        'Fatty Meat': fatty_meat_pattern,
        'Processed Meat': processed_meat_pattern,
        'Red Meat': red_meat_pattern,
        'White Meat': white_meat_pattern,
        'Game Meat': game_meat_pattern,
        'Organ Meat': organ_meats_pattern,
        'Processed Poultry': processed_poultry_pattern,
        'Nuts/Seeds/Soy': nuts_seeds_soy_pattern,
        'Seafood': seafood_pattern,
        'Eggs': eggs_pattern
    }

    found_protein_types = []

    for variety, pattern in protein_type_patterns.items():
        if pattern.search(item):
            found_protein_types.append(variety)

    return ', '.join(found_protein_types) if found_protein_types else 'None'

nutrition['protein_type_new'] = nutrition['name'].apply(protein_source_types_new)

# %%
def protein_source_types_new2(item):
    protein_type_patterns = {
        'Lean Meat': lean_meat_pattern2,
        'Fatty Meat': fatty_meat_pattern2,
        'Processed Meat': processed_meat_pattern2,
        'Red Meat': red_meat_pattern2,
        'White Meat': white_meat_pattern2,
        'Game Meat': game_meat_pattern2,
        'Organ Meat': organ_meats_pattern2,
        'Processed Poultry': processed_poultry_pattern2,
        'Nuts/Seeds/Soy': nuts_seeds_soy_pattern2,
        'Seafood': seafood_pattern2,
        'Eggs': eggs_pattern2
    }

    found_protein_types = []

    for variety, pattern in protein_type_patterns.items():
        if pattern.search(item):
            found_protein_types.append(variety)

    return ', '.join(found_protein_types) if found_protein_types else 'None'

nutrition['protein_type_new2'] = nutrition['name'].apply(protein_source_types_new2)

# %%
# Plot: 

protein_sources_filter_new = nutrition.query("`protein source new?` == True")
f, ax = plt.subplots(figsize=(7, 4))
f.subplots_adjust(wspace=0.1)
sns.countplot(y='protein_type_new', ax=ax, data=protein_sources_filter_new)
ax.set_title('protein type')
ax.set_ylabel('', rotation=0)  # customize the y-axis label
ax.get_yaxis().set_label_coords(-0.25,0.43)  # Adjust y-axis label position
plt.show()

# %%
# Plot: 
protein_sources_filter_new = nutrition.query("`protein source new?` == True")
f, ax = plt.subplots(figsize=(7, 5))
f.subplots_adjust(wspace=0.1)
sns.boxplot(y='protein_type_new', x='NRF_score_adult_scaled', ax=ax, data=protein_sources_filter_new)
ax.set_title('proteins')
ax.set_ylabel('', rotation=0)  # customize the y-axis label
ax.get_yaxis().set_label_coords(-0.25,0.43)  # Adjust y-axis label position
plt.show()

# %%
# Plot: 

protein_sources_filter_new2 = nutrition.query("`protein source new2?` == True")
f, ax = plt.subplots(figsize=(7, 6))
f.subplots_adjust(wspace=0.1)
sns.countplot(y='protein_type_new2', ax=ax, data=protein_sources_filter_new2)
ax.set_title('protein type2')
ax.set_ylabel('', rotation=0)  # customize the y-axis label
ax.get_yaxis().set_label_coords(-0.25,0.43)  # Adjust y-axis label position
plt.show()

# %%
# Plot: 
protein_sources_filter_new2 = nutrition.query("`protein source new2?` == True")
f, ax = plt.subplots(figsize=(7, 6))
f.subplots_adjust(wspace=0.1)
sns.boxplot(y='protein_type_new2', x='NRF_score_adult_scaled', ax=ax, data=protein_sources_filter_new2)
ax.set_title('proteins2')
ax.set_ylabel('', rotation=0)  # customize the y-axis label
ax.get_yaxis().set_label_coords(-0.25,0.43)  # Adjust y-axis label position
plt.show()

# %% [markdown]
# ## Modeling the caloric impact of different macronutrients
# a large chunk of clients seeking nutritional advice do so for weight-loss goals.
# In addition to exploring nutrient density by mass, different macronutrients can be examined for their unique contribution to overall food item calorie content.
# To examine the effect of different macronutrients on

# %% [markdown]
# below--for exporting the cleaned data as needed

# %%
#nutrition.to_csv('nutrition_cleaner.csv', index=False)

# %%
#nutrition_cleaner = pd.read_csv('nutrition_cleaner.csv')
#nutrition_cleaner.head()

# %%
#nutrition_cleaner.drop(columns=['contains_fruit_group', 'contains_fruit', 'contains_fruit_juice', 'contains_vegetable_group', 'contains_dark_green_vegetables', 'contains_red_orange_vegetables', 'contains_beans_peas', 'contains_starchy_vegetables', 'contains_other_vegetables', 'contains_grain_group', 'contains_whole_grain', 'contains_refined_grain', 'contains_protein_group', 'contains_meat_poultry_eggs', 'contains_seafood', 'contains_nuts_seeds_soy', 'contains_dairy_group', 'contains_milk_yogurt', 'contains_cheese'], inplace=True)
#nutrition_cleaner.head()

# %%
#nutrition_cleaner.to_csv('nutrition_cleanest.csv', index=False)
